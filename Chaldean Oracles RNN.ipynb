# %% [markdown]
# # Prepare data

# %%
#Note: original code forked from practical python repo wasn't working. Implement the following suggestions 
#provided by user: BlindElephants:

# loss += criterion(output, target[c])

# should be changed to:

# loss += criterion(output, target[c].unsqueeze(0))

# Change line 54 from this:

# return loss.data[0] / args.chunk_len

#return loss.data.item() / args.chunk_len

# %%
import unidecode
import string
import random
import re
import os

all_characters = string.printable
n_characters = len(all_characters)

cwd = os.getcwd()

values = open(cwd + '/CO.txt', errors='ignore')
values = values.read()
file = unidecode.unidecode(values)
file_len = len(file)
print('file_len =', file_len)
# Out:
# file_len = 268430

# %%
file = file.strip()

# %%
list_of_words = (file.split(" "))

# %%
list_of_words
# Out:
# ['But',
#  'God',
#  'is',
#  'he',
#  'that',
#  'has',
#  'the',
#  'head',
#  'of',
#  'a',
#  'hawk.',
#  'He',
#  'is',
#  'the',
#  'first,',
#  'indestructible,',
#  'eternal,',
#  'unbegotten,',
#  'indivisible,',
#  'dissimilar;',
#  'the',
#  'dispenser',
#  'of',
#  'all',
#  'good;',
#  'incorruptible;',
#  'the',
#  'best',
#  'of',
#  'the',
#  'good,',
#  'the',
#  'wisest',
#  'of',
#  'the',
#  'wise:',
#  'he',
#  'is',
#  'the',
#  'father',
#  'of',
#  'equity',
#  'and',
#  'justice,',
#  'self-taught,',
#  'physical,',
#  'and',
#  'perfect,',
#  'and',
#  'wise,',
#  'and',
#  'the',
#  'only',
#  'inventor',
#  'of',
#  'the',
#  'sacred',
#  'philosophy.\n\t\t\n',
#  '\n\tTheurgists',
#  'assert',
#  'that',
#  'he4',
#  'is',
#  'a',
#  'God,',
#  'and',
#  'celebrate',
#  'him',
#  'as',
#  'both',
#  'older',
#  'and',
#  'younger,',
#  'as',
#  'a',
#  'circulating',
#  'and',
#  'eternal',
#  'God,',
#  'as',
#  'understanding',
#  'the',
#  'whole',
#  'number',
#  'of',
#  'all',
#  'things',
#  'moved',
#  'in',
#  'the',
#  'world,',
#  'and',
#  'moreover',
#  'infinite',
#  'through',
#  'his',
#  'power',
#  'and',
#  'of',
#  'a',
#  'spiral',
#  'form.\n\n',
#  '\nThe',
#  'mundane',
#  'god,',
#  'eternal,',
#  'boundless,\nYoung',
#  'and',
#  'old,',
#  'of',
#  'a',
#  'spiral',
#  'form.\n',
#  '\n\tFor',
#  'Eternity,5',
#  'according',
#  'to',
#  'the',
#  'oracle,',
#  'is',
#  'the',
#  'cause',
#  'of',
#  'never-failing',
#  'life,',
#  'of',
#  'unwearied',
#  'power,',
#  'and',
#  'unsluggish',
#  'energy.\n\n',
#  '\nHence',
#  'this',
#  'stable',
#  'God',
#  'is',
#  'called',
#  'by',
#  'the',
#  'gods',
#  'silent,',
#  'and',
#  'is',
#  'said',
#  'to',
#  'consent',
#  'with',
#  'mind,',
#  'and',
#  'to',
#  'be',
#  'known',
#  'by',
#  'souls',
#  'through',
#  'mind',
#  'alone.\n\t\n',
#  '\n\tThe',
#  'ChaldA|ans',
#  'call',
#  'the',
#  'God',
#  '(Dionysus',
#  'or',
#  'Bacchus)',
#  'Iao',
#  'in',
#  'the',
#  'PhA"nician',
#  'tongue',
#  '(instead',
#  'of',
#  'the',
#  'intelligible',
#  'light),',
#  'and',
#  'he',
#  'is',
#  'often',
#  'called',
#  'Sabaoth,',
#  'signifying',
#  'that',
#  'he',
#  'is',
#  'above',
#  'the',
#  'seven',
#  'poles,',
#  'that',
#  'is',
#  'the',
#  'Demiurgus.\n\t\n',
#  '\n\tContaining',
#  'all',
#  'things',
#  'in',
#  'the',
#  'one',
#  'summit',
#  'of',
#  'his',
#  'own',
#  'hyparxis,',
#  'he',
#  'himself',
#  'subsists',
#  'wholly',
#  'beyond.\n\t\n',
#  '\n\tMeasuring',
#  'and',
#  'bounding',
#  'all',
#  'things.\n\t\n',
#  '\n\tFor',
#  'nothing',
#  'imperfect',
#  'circulates',
#  'from',
#  'a',
#  'paternal',
#  'principle.\n\t\n\tThe',
#  'father',
#  'hurled',
#  'not',
#  'forth',
#  'fear',
#  'but',
#  'infused',
#  'persuasion.\n\t',
#  '',
#  '',
#  '\n',
#  '\n\t.',
#  '.',
#  '.',
#  '.',
#  'The',
#  'Father',
#  'has',
#  'hastily',
#  'withdrawn',
#  'himself;\nBut',
#  'has',
#  'not',
#  'shut',
#  'up',
#  'his',
#  'own',
#  'fire',
#  'in',
#  'his',
#  'intellectual',
#  'power.\n\t',
#  '',
#  '\n',
#  '\n\tSuch',
#  'is',
#  'the',
#  'Mind',
#  'which',
#  'is',
#  'there',
#  'energizing',
#  'before',
#  'energy.\nThat',
#  'it',
#  'has',
#  'not',
#  'gone',
#  'forth',
#  'but',
#  'abode',
#  'in',
#  'the',
#  'paternal',
#  'depth,\nAnd',
#  'in',
#  'the',
#  'adytum',
#  'according',
#  'to',
#  'divinely-nourished',
#  'silence.\n\t',
#  '',
#  '',
#  '\n',
#  '\n\tAll',
#  'things',
#  'are',
#  'the',
#  'progeny',
#  'of',
#  'one',
#  'fire.\nThe',
#  'Father',
#  'perfected',
#  'all',
#  'things,',
#  'and',
#  'delivered',
#  'them',
#  'over\nTo',
#  'the',
#  'second',
#  'Mind,',
#  'whom',
#  'all',
#  'nations',
#  'of',
#  'men',
#  'call',
#  'the',
#  'first.\n\t',
#  '',
#  '',
#  '',
#  '\n',
#  '\nAnd',
#  'of',
#  'the',
#  'Mind',
#  'which',
#  'conducts',
#  'the',
#  'empyrean',
#  'world.\n\t',
#  '\n',
#  '\n\tWhat',
#  'the',
#  'Mind',
#  'says,',
#  'it',
#  'says',
#  'by',
#  'understanding.\n\t',
#  '',
#  '\n',
#  '\n\tPower',
#  'is',
#  'with',
#  'them,',
#  'but',
#  'Mind',
#  'is',
#  'from',
#  'him.\n\t',
#  '',
#  '\n',
#  '\n\tThe',
#  'Mind',
#  'of',
#  'the',
#  'Father',
#  'riding',
#  'on',
#  'attenuated',
#  'rulers\nWhich',
#  'glitter',
#  'with',
#  'the',
#  'furrows',
#  'of',
#  'inflexible',
#  'and',
#  'implacable',
#  'Fire.\n\t',
#  '',
#  '\n',
#  '\n\t.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  'After',
#  'the',
#  'paternal',
#  'conception\nI',
#  'the',
#  'Soul',
#  'reside,',
#  'a',
#  'heat',
#  'animating',
#  'all',
#  'things.\n.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  'For',
#  'he',
#  'placed\nMind',
#  'in',
#  'Soul',
#  'and',
#  'Soul',
#  'in',
#  'dull',
#  'Body,\nThe',
#  'Father',
#  'of',
#  'Gods',
#  'and',
#  'Men',
#  'so',
#  'placed',
#  'them',
#  'in',
#  'ours.\n\t\n',
#  '\n\tNatural',
#  'works',
#  'coexist',
#  'with',
#  'the',
#  'intellectual',
#  'light\nOf',
#  'the',
#  'Father.',
#  'For',
#  'it',
#  'is',
#  'the',
#  'Soul,',
#  'which',
#  'adorned',
#  'the',
#  'great',
#  'heaven\nAnd',
#  'which',
#  'adorns',
#  'it',
#  'after',
#  'the',
#  'Father.\nBut',
#  'her',
#  'horns',
#  'are',
#  'established',
#  'on',
#  'high.\n\t',
#  '\n',
#  '\nThe',
#  'Soul,',
#  'being',
#  'a',
#  'bright',
#  'fire,',
#  'by',
#  'the',
#  'power',
#  'of',
#  'the',
#  'father,\nRemains',
#  'immortal,',
#  'and',
#  'is',
#  'mistress',
#  'of',
#  'life,\nAnd',
#  'fills',
#  'up',
#  'many',
#  'of',
#  'the',
#  'recesses',
#  'of',
#  'the',
#  'world.\n\n',
#  '\n\tThe',
#  'channels',
#  'being',
#  'intermixed,',
#  'she',
#  'performs',
#  'the',
#  'works',
#  'of',
#  'incorruptible',
#  'fire.\n\t\n\tFor',
#  'the',
#  'Fire',
#  'which',
#  'is',
#  'first',
#  'beyond',
#  'did',
#  'not',
#  'shut',
#  'up',
#  'his',
#  'power\nIn',
#  'matter',
#  'by',
#  'works',
#  'but',
#  'by',
#  'mind:\nFor',
#  'the',
#  'framer',
#  'of',
#  'the',
#  'fiery',
#  'world',
#  'is',
#  'the',
#  'Mind',
#  'of',
#  'Mind.\n\n',
#  '\n\tWho',
#  'first',
#  'sprung',
#  'from',
#  'Mind\nClothing',
#  'fire',
#  'with',
#  'fire,',
#  'binding',
#  'them',
#  'together',
#  'that',
#  'he',
#  'might',
#  'mingle\nThe',
#  'fountainous',
#  'craters,',
#  'while',
#  'he',
#  'preserved',
#  'the',
#  'flower',
#  'of',
#  'his',
#  'own',
#  'fire.\n\t\n',
#  '\nThence',
#  'a',
#  'fiery',
#  'whirlwind',
#  'drawing',
#  'the',
#  'flower',
#  'of',
#  'glowing',
#  'fire,\nFlashing',
#  'into',
#  'the',
#  'cavities',
#  'of',
#  'the',
#  'worlds;',
#  'for',
#  'all',
#  'things',
#  'from',
#  'thence\nBegin',
#  'to',
#  'extend',
#  'downwards',
#  'their',
#  'admirable',
#  'rays.\n\t',
#  '',
#  '\n',
#  '\n\tThe',
#  'Monad',
#  'is',
#  'there',
#  'first',
#  'where',
#  'the',
#  'paternal',
#  'Monad',
#  'subsists.\n\t\n',
#  '\n\tThe',
#  'Monad',
#  'is',
#  'extended',
#  'which',
#  'generates',
#  'two.\n\t\n\tFor',
#  'the',
#  'Duad',
#  'sits',
#  'by',
#  'this,',
#  'and',
#  'glitters',
#  'with',
#  'intellectual',
#  'sections,\nTo',
#  'govern',
#  'all',
#  'things,',
#  'and',
#  'to',
#  'order',
#  'each.\n\t',
#  '',
#  '\n',
#  '\n\tThe',
#  'Mind',
#  'of',
#  'the',
#  'Father',
#  'said',
#  'that',
#  'all',
#  'things',
#  'should',
#  'be',
#  'cut',
#  'into',
#  'three:\nHis',
#  'will',
#  'assented,',
#  'and',
#  'immediately',
#  'all',
#  'things',
#  'were',
#  'cut.\n\n',
#  '\tThe',
#  'Mind',
#  'of',
#  'the',
#  'eternal',
#  'Father',
#  'said',
#  'into',
#  'three,\nGoverning',
#  'all',
#  'things',
#  'by',
#  'Mind,\n\n',
#  '\n\tThe',
#  'Father',
#  'mingled',
#  'every',
#  'Spirit',
#  'from',
#  'this',
#  'Triad.\n\t\n',
#  '\n\tAll',
#  'things',
#  'are',
#  'governed',
#  'in',
#  'the',
#  'bosoms',
#  'of',
#  'this',
#  'triad.\n\t\t\n',
#  '\n\tAll',
#  'things',
#  'are',
#  'governed',
#  'and',
#  'subsist',
#  'in',
#  'these',
#  'three.\n\t',
#  '',
#  '\n',
#  '\n\tFor',
#  'you',
#  'may',
#  'conceive',
#  'that',
#  'all',
#  'things',
#  'serve',
#  'these',
#  'three',
#  'principles.\n\t',
#  '',
#  '',
#  '\n',
#  '\n\tFrom',
#  'these',
#  'flows',
#  'the',
#  'body',
#  'of',
#  'the',
#  'Triad,',
#  'being',
#  'pre-existent,\nNot',
#  'the',
#  'first,',
#  'but',
#  'that',
#  'by',
#  'which',
#  'things',
#  'are',
#  'measured.\n\t',
#  '',
#  '\n',
#  '\n\tAnd',
#  'there',
#  'appeared',
#  'in',
#  'it',
#  'virtue,',
#  'and',
#  'wisdom,\nAnd',
#  'multiscient',
#  'truth.\n\t',
#  '',
#  '',
#  '\n',
#  '\n\tFor',
#  'in',
#  'the',
#  'whole',
#  'world',
#  'shineth',
#  'a',
#  'Triad,',
#  'over',
#  'which',
#  'a',
#  'Monad',
#  'rules.\n\t\n',
#  '\n\tThe',
#  'first',
#  'is',
#  'the',
#  'sacred',
#  'course',
#  '.',
#  '.',
#  '.',
#  '.',
#  ',',
#  'but',
#  'in',
#  'the',
#  'middle\nAir,',
#  'the',
#  'third',
#  'the',
#  'other',
#  'which',
#  'cherisheth',
#  'the',
#  'earth',
#  'in',
#  'fire.\n\t',
#  '',
#  '',
#  '',
#  '\n',
#  '\n\tAbundantly',
#  'animating',
#  'light,',
#  'fire,',
#  'ether,',
#  'worlds.\n\t',
#  '',
#  '\n\n',
#  '\n\n\n',
#  '\n\tThe',
#  'Mind',
#  'of',
#  'the',
#  'Father',
#  'made',
#  'a',
#  'jarring',
#  'noise,',
#  'understanding',
#  'by',
#  'unwearied',
#  'counsel\nOmniform',
#  'ideas:',
#  'which',
#  'flying',
#  'out',
#  'from',
#  'one',
#  'fountain\nThey',
#  'sprung',
#  'forth:',
#  'for',
#  'from',
#  'the',
#  'Father',
#  'was',
#  'the',
#  'will',
#  'and',
#  'the',
#  'end;\n(By',
#  'which',
#  'they',
#  'are',
#  'connected',
#  'with',
#  'the',
#  'Father\nAccording',
#  'to',
#  'alternate',
#  'life',
#  'from',
#  'several',
#  'vehicles,)\nBut',
#  'they',
#  'were',
#  'divided,',
#  'being',
#  'by',
#  'intellectual',
#  'fire',
#  'distributed\nInto',
#  'other',
#  'Intellectuals:',
#  'For',
#  'the',
#  'king',
#  'previously',
#  'placed',
#  'before',
#  'the',
#  'multiform',
#  'world\nAn',
#  'intellectual,',
#  'incorruptible',
#  'pattern,',
#  'the',
#  'print',
#  'of',
#  'whose',
#  'form\nIs',
#  'promoted',
#  'through',
#  'the',
#  'world,',
#  'according',
#  'to',
#  'which',
#  'things',
#  'the',
#  'world',
#  'appeared\nBeautified',
#  'with',
#  'all-various',
#  'Ideas;',
#  'of',
#  'which',
#  'there',
#  'is',
#  'one',
#  'fountain,\nFrom',
#  'this',
#  'the',
#  'others',
#  'rush',
#  'forth',
#  'distributed,\nAnd',
#  'separated',
#  'about',
#  'the',
#  'bodies',
#  'of',
#  'the',
#  'world,',
#  'and',
#  'are',
#  'borne\nThrough',
#  'its',
#  'vast',
#  'recesses',
#  'like',
#  'swarms\nTurning',
#  'themselves',
#  'on',
#  'all',
#  'sides',
#  'in',
#  'every',
#  'direction,\nThey',
#  'are',
#  'Intellectual',
#  'conceptions',
#  'from',
#  'the',
#  'paternal',
#  'fountain,\nPartaking',
#  'abundantly',
#  'the',
#  'flower',
#  'of',
#  'Fire',
#  'in',
#  'the',
#  'point',
#  'of',
#  'restless',
#  'time,\nBut',
#  'the',
#  'primary',
#  'self-perfect',
#  'fountain',
#  'of',
#  'the',
#  'Father\nPoured',
#  'forth',
#  'these',
#  'primogenial',
#  'ideas.\n\t\n',
#  '\n\tThese',
#  'being',
#  'many',
#  'ascend',
#  'flashingly',
#  'into',
#  'the',
#  'shining',
#  'worlds\nAnd',
#  'in',
#  'them',
#  'are',
#  'contained',
#  'three',
#  'summits.\n\t\n\tThey',
#  'are',
#  'the',
#  'guardians',
#  'of',
#  'the',
#  'works',
#  'of',
#  'the',
#  'Father\nAnd',
#  'of',
#  'the',
#  'one',
#  'Mind,',
#  'the',
#  'Intelligible.\n\n',
#  '\n\tAll',
#  'things',
#  'subsist',
#  'together',
#  'in',
#  'the',
#  'Intelligible',
#  'world.\n\n',
#  '\n\tBut',
#  'all',
#  'Intellect',
#  'understands',
#  'the',
#  'deity,',
#  'for',
#  'Intellect',
#  'is',
#  'not',
#  'without',
#  'the',
#  'Intelligible,\nAnd',
#  'the',
#  'Intelligible',
#  'does',
#  'not',
#  'subsist',
#  'apart',
#  'from',
#  'Intellect.\n\t',
#  '\n',
#  '\n\tFor',
#  'Intellect',
#  'is',
#  'not',
#  'without',
#  'the',
#  'Intelligible:',
#  'it',
#  'does',
#  'not',
#  'subsist',
#  'apart',
#  'from',
#  'it.\n\t',
#  '\n',
#  '\n\tBy',
#  'Intellect',
#  'he',
#  'contains',
#  'the',
#  'Intelligibles,',
#  'but',
#  'introduces',
#  'the',
#  'Soul',
#  'into',
#  ...]

# %%
pattern = r'[^A-Za-z ]+'

# %%
list_of_words = [re.sub(pattern, '', word) for word in list_of_words]

# %%
list_of_words
# Out:
# ['But',
#  'God',
#  'is',
#  'he',
#  'that',
#  'has',
#  'the',
#  'head',
#  'of',
#  'a',
#  'hawk',
#  'He',
#  'is',
#  'the',
#  'first',
#  'indestructible',
#  'eternal',
#  'unbegotten',
#  'indivisible',
#  'dissimilar',
#  'the',
#  'dispenser',
#  'of',
#  'all',
#  'good',
#  'incorruptible',
#  'the',
#  'best',
#  'of',
#  'the',
#  'good',
#  'the',
#  'wisest',
#  'of',
#  'the',
#  'wise',
#  'he',
#  'is',
#  'the',
#  'father',
#  'of',
#  'equity',
#  'and',
#  'justice',
#  'selftaught',
#  'physical',
#  'and',
#  'perfect',
#  'and',
#  'wise',
#  'and',
#  'the',
#  'only',
#  'inventor',
#  'of',
#  'the',
#  'sacred',
#  'philosophy',
#  'Theurgists',
#  'assert',
#  'that',
#  'he',
#  'is',
#  'a',
#  'God',
#  'and',
#  'celebrate',
#  'him',
#  'as',
#  'both',
#  'older',
#  'and',
#  'younger',
#  'as',
#  'a',
#  'circulating',
#  'and',
#  'eternal',
#  'God',
#  'as',
#  'understanding',
#  'the',
#  'whole',
#  'number',
#  'of',
#  'all',
#  'things',
#  'moved',
#  'in',
#  'the',
#  'world',
#  'and',
#  'moreover',
#  'infinite',
#  'through',
#  'his',
#  'power',
#  'and',
#  'of',
#  'a',
#  'spiral',
#  'form',
#  'The',
#  'mundane',
#  'god',
#  'eternal',
#  'boundlessYoung',
#  'and',
#  'old',
#  'of',
#  'a',
#  'spiral',
#  'form',
#  'For',
#  'Eternity',
#  'according',
#  'to',
#  'the',
#  'oracle',
#  'is',
#  'the',
#  'cause',
#  'of',
#  'neverfailing',
#  'life',
#  'of',
#  'unwearied',
#  'power',
#  'and',
#  'unsluggish',
#  'energy',
#  'Hence',
#  'this',
#  'stable',
#  'God',
#  'is',
#  'called',
#  'by',
#  'the',
#  'gods',
#  'silent',
#  'and',
#  'is',
#  'said',
#  'to',
#  'consent',
#  'with',
#  'mind',
#  'and',
#  'to',
#  'be',
#  'known',
#  'by',
#  'souls',
#  'through',
#  'mind',
#  'alone',
#  'The',
#  'ChaldAans',
#  'call',
#  'the',
#  'God',
#  'Dionysus',
#  'or',
#  'Bacchus',
#  'Iao',
#  'in',
#  'the',
#  'PhAnician',
#  'tongue',
#  'instead',
#  'of',
#  'the',
#  'intelligible',
#  'light',
#  'and',
#  'he',
#  'is',
#  'often',
#  'called',
#  'Sabaoth',
#  'signifying',
#  'that',
#  'he',
#  'is',
#  'above',
#  'the',
#  'seven',
#  'poles',
#  'that',
#  'is',
#  'the',
#  'Demiurgus',
#  'Containing',
#  'all',
#  'things',
#  'in',
#  'the',
#  'one',
#  'summit',
#  'of',
#  'his',
#  'own',
#  'hyparxis',
#  'he',
#  'himself',
#  'subsists',
#  'wholly',
#  'beyond',
#  'Measuring',
#  'and',
#  'bounding',
#  'all',
#  'things',
#  'For',
#  'nothing',
#  'imperfect',
#  'circulates',
#  'from',
#  'a',
#  'paternal',
#  'principleThe',
#  'father',
#  'hurled',
#  'not',
#  'forth',
#  'fear',
#  'but',
#  'infused',
#  'persuasion',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'The',
#  'Father',
#  'has',
#  'hastily',
#  'withdrawn',
#  'himselfBut',
#  'has',
#  'not',
#  'shut',
#  'up',
#  'his',
#  'own',
#  'fire',
#  'in',
#  'his',
#  'intellectual',
#  'power',
#  '',
#  '',
#  'Such',
#  'is',
#  'the',
#  'Mind',
#  'which',
#  'is',
#  'there',
#  'energizing',
#  'before',
#  'energyThat',
#  'it',
#  'has',
#  'not',
#  'gone',
#  'forth',
#  'but',
#  'abode',
#  'in',
#  'the',
#  'paternal',
#  'depthAnd',
#  'in',
#  'the',
#  'adytum',
#  'according',
#  'to',
#  'divinelynourished',
#  'silence',
#  '',
#  '',
#  '',
#  'All',
#  'things',
#  'are',
#  'the',
#  'progeny',
#  'of',
#  'one',
#  'fireThe',
#  'Father',
#  'perfected',
#  'all',
#  'things',
#  'and',
#  'delivered',
#  'them',
#  'overTo',
#  'the',
#  'second',
#  'Mind',
#  'whom',
#  'all',
#  'nations',
#  'of',
#  'men',
#  'call',
#  'the',
#  'first',
#  '',
#  '',
#  '',
#  '',
#  'And',
#  'of',
#  'the',
#  'Mind',
#  'which',
#  'conducts',
#  'the',
#  'empyrean',
#  'world',
#  '',
#  'What',
#  'the',
#  'Mind',
#  'says',
#  'it',
#  'says',
#  'by',
#  'understanding',
#  '',
#  '',
#  'Power',
#  'is',
#  'with',
#  'them',
#  'but',
#  'Mind',
#  'is',
#  'from',
#  'him',
#  '',
#  '',
#  'The',
#  'Mind',
#  'of',
#  'the',
#  'Father',
#  'riding',
#  'on',
#  'attenuated',
#  'rulersWhich',
#  'glitter',
#  'with',
#  'the',
#  'furrows',
#  'of',
#  'inflexible',
#  'and',
#  'implacable',
#  'Fire',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'After',
#  'the',
#  'paternal',
#  'conceptionI',
#  'the',
#  'Soul',
#  'reside',
#  'a',
#  'heat',
#  'animating',
#  'all',
#  'things',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'For',
#  'he',
#  'placedMind',
#  'in',
#  'Soul',
#  'and',
#  'Soul',
#  'in',
#  'dull',
#  'BodyThe',
#  'Father',
#  'of',
#  'Gods',
#  'and',
#  'Men',
#  'so',
#  'placed',
#  'them',
#  'in',
#  'ours',
#  'Natural',
#  'works',
#  'coexist',
#  'with',
#  'the',
#  'intellectual',
#  'lightOf',
#  'the',
#  'Father',
#  'For',
#  'it',
#  'is',
#  'the',
#  'Soul',
#  'which',
#  'adorned',
#  'the',
#  'great',
#  'heavenAnd',
#  'which',
#  'adorns',
#  'it',
#  'after',
#  'the',
#  'FatherBut',
#  'her',
#  'horns',
#  'are',
#  'established',
#  'on',
#  'high',
#  '',
#  'The',
#  'Soul',
#  'being',
#  'a',
#  'bright',
#  'fire',
#  'by',
#  'the',
#  'power',
#  'of',
#  'the',
#  'fatherRemains',
#  'immortal',
#  'and',
#  'is',
#  'mistress',
#  'of',
#  'lifeAnd',
#  'fills',
#  'up',
#  'many',
#  'of',
#  'the',
#  'recesses',
#  'of',
#  'the',
#  'world',
#  'The',
#  'channels',
#  'being',
#  'intermixed',
#  'she',
#  'performs',
#  'the',
#  'works',
#  'of',
#  'incorruptible',
#  'fireFor',
#  'the',
#  'Fire',
#  'which',
#  'is',
#  'first',
#  'beyond',
#  'did',
#  'not',
#  'shut',
#  'up',
#  'his',
#  'powerIn',
#  'matter',
#  'by',
#  'works',
#  'but',
#  'by',
#  'mindFor',
#  'the',
#  'framer',
#  'of',
#  'the',
#  'fiery',
#  'world',
#  'is',
#  'the',
#  'Mind',
#  'of',
#  'Mind',
#  'Who',
#  'first',
#  'sprung',
#  'from',
#  'MindClothing',
#  'fire',
#  'with',
#  'fire',
#  'binding',
#  'them',
#  'together',
#  'that',
#  'he',
#  'might',
#  'mingleThe',
#  'fountainous',
#  'craters',
#  'while',
#  'he',
#  'preserved',
#  'the',
#  'flower',
#  'of',
#  'his',
#  'own',
#  'fire',
#  'Thence',
#  'a',
#  'fiery',
#  'whirlwind',
#  'drawing',
#  'the',
#  'flower',
#  'of',
#  'glowing',
#  'fireFlashing',
#  'into',
#  'the',
#  'cavities',
#  'of',
#  'the',
#  'worlds',
#  'for',
#  'all',
#  'things',
#  'from',
#  'thenceBegin',
#  'to',
#  'extend',
#  'downwards',
#  'their',
#  'admirable',
#  'rays',
#  '',
#  '',
#  'The',
#  'Monad',
#  'is',
#  'there',
#  'first',
#  'where',
#  'the',
#  'paternal',
#  'Monad',
#  'subsists',
#  'The',
#  'Monad',
#  'is',
#  'extended',
#  'which',
#  'generates',
#  'twoFor',
#  'the',
#  'Duad',
#  'sits',
#  'by',
#  'this',
#  'and',
#  'glitters',
#  'with',
#  'intellectual',
#  'sectionsTo',
#  'govern',
#  'all',
#  'things',
#  'and',
#  'to',
#  'order',
#  'each',
#  '',
#  '',
#  'The',
#  'Mind',
#  'of',
#  'the',
#  'Father',
#  'said',
#  'that',
#  'all',
#  'things',
#  'should',
#  'be',
#  'cut',
#  'into',
#  'threeHis',
#  'will',
#  'assented',
#  'and',
#  'immediately',
#  'all',
#  'things',
#  'were',
#  'cut',
#  'The',
#  'Mind',
#  'of',
#  'the',
#  'eternal',
#  'Father',
#  'said',
#  'into',
#  'threeGoverning',
#  'all',
#  'things',
#  'by',
#  'Mind',
#  'The',
#  'Father',
#  'mingled',
#  'every',
#  'Spirit',
#  'from',
#  'this',
#  'Triad',
#  'All',
#  'things',
#  'are',
#  'governed',
#  'in',
#  'the',
#  'bosoms',
#  'of',
#  'this',
#  'triad',
#  'All',
#  'things',
#  'are',
#  'governed',
#  'and',
#  'subsist',
#  'in',
#  'these',
#  'three',
#  '',
#  '',
#  'For',
#  'you',
#  'may',
#  'conceive',
#  'that',
#  'all',
#  'things',
#  'serve',
#  'these',
#  'three',
#  'principles',
#  '',
#  '',
#  '',
#  'From',
#  'these',
#  'flows',
#  'the',
#  'body',
#  'of',
#  'the',
#  'Triad',
#  'being',
#  'preexistentNot',
#  'the',
#  'first',
#  'but',
#  'that',
#  'by',
#  'which',
#  'things',
#  'are',
#  'measured',
#  '',
#  '',
#  'And',
#  'there',
#  'appeared',
#  'in',
#  'it',
#  'virtue',
#  'and',
#  'wisdomAnd',
#  'multiscient',
#  'truth',
#  '',
#  '',
#  '',
#  'For',
#  'in',
#  'the',
#  'whole',
#  'world',
#  'shineth',
#  'a',
#  'Triad',
#  'over',
#  'which',
#  'a',
#  'Monad',
#  'rules',
#  'The',
#  'first',
#  'is',
#  'the',
#  'sacred',
#  'course',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'but',
#  'in',
#  'the',
#  'middleAir',
#  'the',
#  'third',
#  'the',
#  'other',
#  'which',
#  'cherisheth',
#  'the',
#  'earth',
#  'in',
#  'fire',
#  '',
#  '',
#  '',
#  '',
#  'Abundantly',
#  'animating',
#  'light',
#  'fire',
#  'ether',
#  'worlds',
#  '',
#  '',
#  '',
#  'The',
#  'Mind',
#  'of',
#  'the',
#  'Father',
#  'made',
#  'a',
#  'jarring',
#  'noise',
#  'understanding',
#  'by',
#  'unwearied',
#  'counselOmniform',
#  'ideas',
#  'which',
#  'flying',
#  'out',
#  'from',
#  'one',
#  'fountainThey',
#  'sprung',
#  'forth',
#  'for',
#  'from',
#  'the',
#  'Father',
#  'was',
#  'the',
#  'will',
#  'and',
#  'the',
#  'endBy',
#  'which',
#  'they',
#  'are',
#  'connected',
#  'with',
#  'the',
#  'FatherAccording',
#  'to',
#  'alternate',
#  'life',
#  'from',
#  'several',
#  'vehiclesBut',
#  'they',
#  'were',
#  'divided',
#  'being',
#  'by',
#  'intellectual',
#  'fire',
#  'distributedInto',
#  'other',
#  'Intellectuals',
#  'For',
#  'the',
#  'king',
#  'previously',
#  'placed',
#  'before',
#  'the',
#  'multiform',
#  'worldAn',
#  'intellectual',
#  'incorruptible',
#  'pattern',
#  'the',
#  'print',
#  'of',
#  'whose',
#  'formIs',
#  'promoted',
#  'through',
#  'the',
#  'world',
#  'according',
#  'to',
#  'which',
#  'things',
#  'the',
#  'world',
#  'appearedBeautified',
#  'with',
#  'allvarious',
#  'Ideas',
#  'of',
#  'which',
#  'there',
#  'is',
#  'one',
#  'fountainFrom',
#  'this',
#  'the',
#  'others',
#  'rush',
#  'forth',
#  'distributedAnd',
#  'separated',
#  'about',
#  'the',
#  'bodies',
#  'of',
#  'the',
#  'world',
#  'and',
#  'are',
#  'borneThrough',
#  'its',
#  'vast',
#  'recesses',
#  'like',
#  'swarmsTurning',
#  'themselves',
#  'on',
#  'all',
#  'sides',
#  'in',
#  'every',
#  'directionThey',
#  'are',
#  'Intellectual',
#  'conceptions',
#  'from',
#  'the',
#  'paternal',
#  'fountainPartaking',
#  'abundantly',
#  'the',
#  'flower',
#  'of',
#  'Fire',
#  'in',
#  'the',
#  'point',
#  'of',
#  'restless',
#  'timeBut',
#  'the',
#  'primary',
#  'selfperfect',
#  'fountain',
#  'of',
#  'the',
#  'FatherPoured',
#  'forth',
#  'these',
#  'primogenial',
#  'ideas',
#  'These',
#  'being',
#  'many',
#  'ascend',
#  'flashingly',
#  'into',
#  'the',
#  'shining',
#  'worldsAnd',
#  'in',
#  'them',
#  'are',
#  'contained',
#  'three',
#  'summitsThey',
#  'are',
#  'the',
#  'guardians',
#  'of',
#  'the',
#  'works',
#  'of',
#  'the',
#  'FatherAnd',
#  'of',
#  'the',
#  'one',
#  'Mind',
#  'the',
#  'Intelligible',
#  'All',
#  'things',
#  'subsist',
#  'together',
#  'in',
#  'the',
#  'Intelligible',
#  'world',
#  'But',
#  'all',
#  'Intellect',
#  'understands',
#  'the',
#  'deity',
#  'for',
#  'Intellect',
#  'is',
#  'not',
#  'without',
#  'the',
#  'IntelligibleAnd',
#  'the',
#  'Intelligible',
#  'does',
#  'not',
#  'subsist',
#  'apart',
#  'from',
#  'Intellect',
#  '',
#  'For',
#  'Intellect',
#  'is',
#  'not',
#  'without',
#  'the',
#  'Intelligible',
#  'it',
#  'does',
#  'not',
#  'subsist',
#  'apart',
#  'from',
#  'it',
#  '',
#  'By',
#  'Intellect',
#  'he',
#  'contains',
#  'the',
#  'Intelligibles',
#  'but',
#  'introduces',
#  'the',
#  'Soul',
#  'into',
#  ...]

# %%
list_of_words = [word.lower() for word in list_of_words]

# %%
list_of_words
# Out:
# ['but',
#  'god',
#  'is',
#  'he',
#  'that',
#  'has',
#  'the',
#  'head',
#  'of',
#  'a',
#  'hawk',
#  'he',
#  'is',
#  'the',
#  'first',
#  'indestructible',
#  'eternal',
#  'unbegotten',
#  'indivisible',
#  'dissimilar',
#  'the',
#  'dispenser',
#  'of',
#  'all',
#  'good',
#  'incorruptible',
#  'the',
#  'best',
#  'of',
#  'the',
#  'good',
#  'the',
#  'wisest',
#  'of',
#  'the',
#  'wise',
#  'he',
#  'is',
#  'the',
#  'father',
#  'of',
#  'equity',
#  'and',
#  'justice',
#  'selftaught',
#  'physical',
#  'and',
#  'perfect',
#  'and',
#  'wise',
#  'and',
#  'the',
#  'only',
#  'inventor',
#  'of',
#  'the',
#  'sacred',
#  'philosophy',
#  'theurgists',
#  'assert',
#  'that',
#  'he',
#  'is',
#  'a',
#  'god',
#  'and',
#  'celebrate',
#  'him',
#  'as',
#  'both',
#  'older',
#  'and',
#  'younger',
#  'as',
#  'a',
#  'circulating',
#  'and',
#  'eternal',
#  'god',
#  'as',
#  'understanding',
#  'the',
#  'whole',
#  'number',
#  'of',
#  'all',
#  'things',
#  'moved',
#  'in',
#  'the',
#  'world',
#  'and',
#  'moreover',
#  'infinite',
#  'through',
#  'his',
#  'power',
#  'and',
#  'of',
#  'a',
#  'spiral',
#  'form',
#  'the',
#  'mundane',
#  'god',
#  'eternal',
#  'boundlessyoung',
#  'and',
#  'old',
#  'of',
#  'a',
#  'spiral',
#  'form',
#  'for',
#  'eternity',
#  'according',
#  'to',
#  'the',
#  'oracle',
#  'is',
#  'the',
#  'cause',
#  'of',
#  'neverfailing',
#  'life',
#  'of',
#  'unwearied',
#  'power',
#  'and',
#  'unsluggish',
#  'energy',
#  'hence',
#  'this',
#  'stable',
#  'god',
#  'is',
#  'called',
#  'by',
#  'the',
#  'gods',
#  'silent',
#  'and',
#  'is',
#  'said',
#  'to',
#  'consent',
#  'with',
#  'mind',
#  'and',
#  'to',
#  'be',
#  'known',
#  'by',
#  'souls',
#  'through',
#  'mind',
#  'alone',
#  'the',
#  'chaldaans',
#  'call',
#  'the',
#  'god',
#  'dionysus',
#  'or',
#  'bacchus',
#  'iao',
#  'in',
#  'the',
#  'phanician',
#  'tongue',
#  'instead',
#  'of',
#  'the',
#  'intelligible',
#  'light',
#  'and',
#  'he',
#  'is',
#  'often',
#  'called',
#  'sabaoth',
#  'signifying',
#  'that',
#  'he',
#  'is',
#  'above',
#  'the',
#  'seven',
#  'poles',
#  'that',
#  'is',
#  'the',
#  'demiurgus',
#  'containing',
#  'all',
#  'things',
#  'in',
#  'the',
#  'one',
#  'summit',
#  'of',
#  'his',
#  'own',
#  'hyparxis',
#  'he',
#  'himself',
#  'subsists',
#  'wholly',
#  'beyond',
#  'measuring',
#  'and',
#  'bounding',
#  'all',
#  'things',
#  'for',
#  'nothing',
#  'imperfect',
#  'circulates',
#  'from',
#  'a',
#  'paternal',
#  'principlethe',
#  'father',
#  'hurled',
#  'not',
#  'forth',
#  'fear',
#  'but',
#  'infused',
#  'persuasion',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'the',
#  'father',
#  'has',
#  'hastily',
#  'withdrawn',
#  'himselfbut',
#  'has',
#  'not',
#  'shut',
#  'up',
#  'his',
#  'own',
#  'fire',
#  'in',
#  'his',
#  'intellectual',
#  'power',
#  '',
#  '',
#  'such',
#  'is',
#  'the',
#  'mind',
#  'which',
#  'is',
#  'there',
#  'energizing',
#  'before',
#  'energythat',
#  'it',
#  'has',
#  'not',
#  'gone',
#  'forth',
#  'but',
#  'abode',
#  'in',
#  'the',
#  'paternal',
#  'depthand',
#  'in',
#  'the',
#  'adytum',
#  'according',
#  'to',
#  'divinelynourished',
#  'silence',
#  '',
#  '',
#  '',
#  'all',
#  'things',
#  'are',
#  'the',
#  'progeny',
#  'of',
#  'one',
#  'firethe',
#  'father',
#  'perfected',
#  'all',
#  'things',
#  'and',
#  'delivered',
#  'them',
#  'overto',
#  'the',
#  'second',
#  'mind',
#  'whom',
#  'all',
#  'nations',
#  'of',
#  'men',
#  'call',
#  'the',
#  'first',
#  '',
#  '',
#  '',
#  '',
#  'and',
#  'of',
#  'the',
#  'mind',
#  'which',
#  'conducts',
#  'the',
#  'empyrean',
#  'world',
#  '',
#  'what',
#  'the',
#  'mind',
#  'says',
#  'it',
#  'says',
#  'by',
#  'understanding',
#  '',
#  '',
#  'power',
#  'is',
#  'with',
#  'them',
#  'but',
#  'mind',
#  'is',
#  'from',
#  'him',
#  '',
#  '',
#  'the',
#  'mind',
#  'of',
#  'the',
#  'father',
#  'riding',
#  'on',
#  'attenuated',
#  'rulerswhich',
#  'glitter',
#  'with',
#  'the',
#  'furrows',
#  'of',
#  'inflexible',
#  'and',
#  'implacable',
#  'fire',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'after',
#  'the',
#  'paternal',
#  'conceptioni',
#  'the',
#  'soul',
#  'reside',
#  'a',
#  'heat',
#  'animating',
#  'all',
#  'things',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'for',
#  'he',
#  'placedmind',
#  'in',
#  'soul',
#  'and',
#  'soul',
#  'in',
#  'dull',
#  'bodythe',
#  'father',
#  'of',
#  'gods',
#  'and',
#  'men',
#  'so',
#  'placed',
#  'them',
#  'in',
#  'ours',
#  'natural',
#  'works',
#  'coexist',
#  'with',
#  'the',
#  'intellectual',
#  'lightof',
#  'the',
#  'father',
#  'for',
#  'it',
#  'is',
#  'the',
#  'soul',
#  'which',
#  'adorned',
#  'the',
#  'great',
#  'heavenand',
#  'which',
#  'adorns',
#  'it',
#  'after',
#  'the',
#  'fatherbut',
#  'her',
#  'horns',
#  'are',
#  'established',
#  'on',
#  'high',
#  '',
#  'the',
#  'soul',
#  'being',
#  'a',
#  'bright',
#  'fire',
#  'by',
#  'the',
#  'power',
#  'of',
#  'the',
#  'fatherremains',
#  'immortal',
#  'and',
#  'is',
#  'mistress',
#  'of',
#  'lifeand',
#  'fills',
#  'up',
#  'many',
#  'of',
#  'the',
#  'recesses',
#  'of',
#  'the',
#  'world',
#  'the',
#  'channels',
#  'being',
#  'intermixed',
#  'she',
#  'performs',
#  'the',
#  'works',
#  'of',
#  'incorruptible',
#  'firefor',
#  'the',
#  'fire',
#  'which',
#  'is',
#  'first',
#  'beyond',
#  'did',
#  'not',
#  'shut',
#  'up',
#  'his',
#  'powerin',
#  'matter',
#  'by',
#  'works',
#  'but',
#  'by',
#  'mindfor',
#  'the',
#  'framer',
#  'of',
#  'the',
#  'fiery',
#  'world',
#  'is',
#  'the',
#  'mind',
#  'of',
#  'mind',
#  'who',
#  'first',
#  'sprung',
#  'from',
#  'mindclothing',
#  'fire',
#  'with',
#  'fire',
#  'binding',
#  'them',
#  'together',
#  'that',
#  'he',
#  'might',
#  'minglethe',
#  'fountainous',
#  'craters',
#  'while',
#  'he',
#  'preserved',
#  'the',
#  'flower',
#  'of',
#  'his',
#  'own',
#  'fire',
#  'thence',
#  'a',
#  'fiery',
#  'whirlwind',
#  'drawing',
#  'the',
#  'flower',
#  'of',
#  'glowing',
#  'fireflashing',
#  'into',
#  'the',
#  'cavities',
#  'of',
#  'the',
#  'worlds',
#  'for',
#  'all',
#  'things',
#  'from',
#  'thencebegin',
#  'to',
#  'extend',
#  'downwards',
#  'their',
#  'admirable',
#  'rays',
#  '',
#  '',
#  'the',
#  'monad',
#  'is',
#  'there',
#  'first',
#  'where',
#  'the',
#  'paternal',
#  'monad',
#  'subsists',
#  'the',
#  'monad',
#  'is',
#  'extended',
#  'which',
#  'generates',
#  'twofor',
#  'the',
#  'duad',
#  'sits',
#  'by',
#  'this',
#  'and',
#  'glitters',
#  'with',
#  'intellectual',
#  'sectionsto',
#  'govern',
#  'all',
#  'things',
#  'and',
#  'to',
#  'order',
#  'each',
#  '',
#  '',
#  'the',
#  'mind',
#  'of',
#  'the',
#  'father',
#  'said',
#  'that',
#  'all',
#  'things',
#  'should',
#  'be',
#  'cut',
#  'into',
#  'threehis',
#  'will',
#  'assented',
#  'and',
#  'immediately',
#  'all',
#  'things',
#  'were',
#  'cut',
#  'the',
#  'mind',
#  'of',
#  'the',
#  'eternal',
#  'father',
#  'said',
#  'into',
#  'threegoverning',
#  'all',
#  'things',
#  'by',
#  'mind',
#  'the',
#  'father',
#  'mingled',
#  'every',
#  'spirit',
#  'from',
#  'this',
#  'triad',
#  'all',
#  'things',
#  'are',
#  'governed',
#  'in',
#  'the',
#  'bosoms',
#  'of',
#  'this',
#  'triad',
#  'all',
#  'things',
#  'are',
#  'governed',
#  'and',
#  'subsist',
#  'in',
#  'these',
#  'three',
#  '',
#  '',
#  'for',
#  'you',
#  'may',
#  'conceive',
#  'that',
#  'all',
#  'things',
#  'serve',
#  'these',
#  'three',
#  'principles',
#  '',
#  '',
#  '',
#  'from',
#  'these',
#  'flows',
#  'the',
#  'body',
#  'of',
#  'the',
#  'triad',
#  'being',
#  'preexistentnot',
#  'the',
#  'first',
#  'but',
#  'that',
#  'by',
#  'which',
#  'things',
#  'are',
#  'measured',
#  '',
#  '',
#  'and',
#  'there',
#  'appeared',
#  'in',
#  'it',
#  'virtue',
#  'and',
#  'wisdomand',
#  'multiscient',
#  'truth',
#  '',
#  '',
#  '',
#  'for',
#  'in',
#  'the',
#  'whole',
#  'world',
#  'shineth',
#  'a',
#  'triad',
#  'over',
#  'which',
#  'a',
#  'monad',
#  'rules',
#  'the',
#  'first',
#  'is',
#  'the',
#  'sacred',
#  'course',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'but',
#  'in',
#  'the',
#  'middleair',
#  'the',
#  'third',
#  'the',
#  'other',
#  'which',
#  'cherisheth',
#  'the',
#  'earth',
#  'in',
#  'fire',
#  '',
#  '',
#  '',
#  '',
#  'abundantly',
#  'animating',
#  'light',
#  'fire',
#  'ether',
#  'worlds',
#  '',
#  '',
#  '',
#  'the',
#  'mind',
#  'of',
#  'the',
#  'father',
#  'made',
#  'a',
#  'jarring',
#  'noise',
#  'understanding',
#  'by',
#  'unwearied',
#  'counselomniform',
#  'ideas',
#  'which',
#  'flying',
#  'out',
#  'from',
#  'one',
#  'fountainthey',
#  'sprung',
#  'forth',
#  'for',
#  'from',
#  'the',
#  'father',
#  'was',
#  'the',
#  'will',
#  'and',
#  'the',
#  'endby',
#  'which',
#  'they',
#  'are',
#  'connected',
#  'with',
#  'the',
#  'fatheraccording',
#  'to',
#  'alternate',
#  'life',
#  'from',
#  'several',
#  'vehiclesbut',
#  'they',
#  'were',
#  'divided',
#  'being',
#  'by',
#  'intellectual',
#  'fire',
#  'distributedinto',
#  'other',
#  'intellectuals',
#  'for',
#  'the',
#  'king',
#  'previously',
#  'placed',
#  'before',
#  'the',
#  'multiform',
#  'worldan',
#  'intellectual',
#  'incorruptible',
#  'pattern',
#  'the',
#  'print',
#  'of',
#  'whose',
#  'formis',
#  'promoted',
#  'through',
#  'the',
#  'world',
#  'according',
#  'to',
#  'which',
#  'things',
#  'the',
#  'world',
#  'appearedbeautified',
#  'with',
#  'allvarious',
#  'ideas',
#  'of',
#  'which',
#  'there',
#  'is',
#  'one',
#  'fountainfrom',
#  'this',
#  'the',
#  'others',
#  'rush',
#  'forth',
#  'distributedand',
#  'separated',
#  'about',
#  'the',
#  'bodies',
#  'of',
#  'the',
#  'world',
#  'and',
#  'are',
#  'bornethrough',
#  'its',
#  'vast',
#  'recesses',
#  'like',
#  'swarmsturning',
#  'themselves',
#  'on',
#  'all',
#  'sides',
#  'in',
#  'every',
#  'directionthey',
#  'are',
#  'intellectual',
#  'conceptions',
#  'from',
#  'the',
#  'paternal',
#  'fountainpartaking',
#  'abundantly',
#  'the',
#  'flower',
#  'of',
#  'fire',
#  'in',
#  'the',
#  'point',
#  'of',
#  'restless',
#  'timebut',
#  'the',
#  'primary',
#  'selfperfect',
#  'fountain',
#  'of',
#  'the',
#  'fatherpoured',
#  'forth',
#  'these',
#  'primogenial',
#  'ideas',
#  'these',
#  'being',
#  'many',
#  'ascend',
#  'flashingly',
#  'into',
#  'the',
#  'shining',
#  'worldsand',
#  'in',
#  'them',
#  'are',
#  'contained',
#  'three',
#  'summitsthey',
#  'are',
#  'the',
#  'guardians',
#  'of',
#  'the',
#  'works',
#  'of',
#  'the',
#  'fatherand',
#  'of',
#  'the',
#  'one',
#  'mind',
#  'the',
#  'intelligible',
#  'all',
#  'things',
#  'subsist',
#  'together',
#  'in',
#  'the',
#  'intelligible',
#  'world',
#  'but',
#  'all',
#  'intellect',
#  'understands',
#  'the',
#  'deity',
#  'for',
#  'intellect',
#  'is',
#  'not',
#  'without',
#  'the',
#  'intelligibleand',
#  'the',
#  'intelligible',
#  'does',
#  'not',
#  'subsist',
#  'apart',
#  'from',
#  'intellect',
#  '',
#  'for',
#  'intellect',
#  'is',
#  'not',
#  'without',
#  'the',
#  'intelligible',
#  'it',
#  'does',
#  'not',
#  'subsist',
#  'apart',
#  'from',
#  'it',
#  '',
#  'by',
#  'intellect',
#  'he',
#  'contains',
#  'the',
#  'intelligibles',
#  'but',
#  'introduces',
#  'the',
#  'soul',
#  'into',
#  ...]

# %%
#get only unique words

# %%
list_of_words = list(set(list_of_words))

# %%
#Try filtering on only existing words... this can take a long time

# %%
import nltk
nltk.download('words')

from nltk.corpus import words

real_words = []
for word in list_of_words:
    if word in words.words():
        real_words.append(word)
    if list_of_words.index(word) % 100 == 0:
        print("Now serving {} / {}".format(list_of_words.index(word), len(list_of_words)))
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\Nick\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# Now serving 0 / 1231
# Now serving 100 / 1231
# Now serving 200 / 1231
# Now serving 300 / 1231
# Now serving 400 / 1231
# Now serving 500 / 1231
# Now serving 600 / 1231
# Now serving 700 / 1231
# Now serving 800 / 1231
# Now serving 900 / 1231
# Now serving 1000 / 1231
# Now serving 1100 / 1231
# Now serving 1200 / 1231

# %%
 len(real_words)
# Out:
# 761

# %%
import json
with open('CO_real_words.txt', 'w') as f:
    f.write(json.dumps(real_words))

# %%
with open('CO_real_words.txt', 'r') as f:
    a = json.loads(f.read())

# %% [markdown]
# To make inputs out of this big string of data, we will be splitting it into chunks.

# %%
chunk_len = 100

def random_chunk():
    start_index = random.randint(0, file_len - chunk_len)
    end_index = start_index + chunk_len + 1
    return file[start_index:end_index]

print(random_chunk())
# Out:
# dane paternal depth.
#
#
# 	Things divine are not attainable by mortals who understand body,
# But only

# %% [markdown]
# # Build the Model
#
# This model will take as input the character for step $t_{-1}$ and is expected to output the next character $t$. There are three layers - one linear layer that encodes the input character into an internal state, one GRU layer (which may itself have multiple layers) that operates on that internal state and a hidden state, and a decoder layer that outputs the probability distribution.

# %%
import torch
import torch.nn as nn
from torch.autograd import Variable

class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, n_layers=1):
        super(RNN, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.n_layers = n_layers
        
        self.encoder = nn.Embedding(input_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size, n_layers)
        self.decoder = nn.Linear(hidden_size, output_size)
    
    def forward(self, input, hidden):
        input = self.encoder(input.view(1, -1))
        output, hidden = self.gru(input.view(1, 1, -1), hidden)
        output = self.decoder(output.view(1, -1))
        return output, hidden

    def init_hidden(self):
        return Variable(torch.zeros(self.n_layers, 1, self.hidden_size))

# %% [markdown]
# # Inputs and Targets

# %% [markdown]
# Each chunk will be turned into a tensor, specifically a `LongTensor` (used for integer values), by looping through the characters of the string and looking up the index of each character in `all_characters`.

# %%
# Turn string into list of longs
def char_tensor(string):
    tensor = torch.zeros(len(string)).long()
    for c in range(len(string)):
        tensor[c] = all_characters.index(string[c])
    return Variable(tensor)

print(char_tensor('abcDEF'))
# Out:
# tensor([10, 11, 12, 39, 40, 41])

# %% [markdown]
# Finally we can assemble a pair of input and target tensors for training, from a random chunk. The input will be all characters *up to the last*, and the target will be all characters *from the first*. So if our chunk is "abc" the input will correspond to "ab" while the target is "bc".

# %%
def random_training_set():    
    chunk = random_chunk()
    inp = char_tensor(chunk[:-1])
    target = char_tensor(chunk[1:])
    return inp, target

# %% [markdown]
# # Evaluating
#
# To evaluate the network we will feed one character at a time, use the outputs of the network as a probability distribution for the next character, and repeat. To start generation we pass a priming string to start building up the hidden state, from which we then generate one character at a time.

# %%
def evaluate(prime_str='A', predict_len=50, temperature=0.8):
    hidden = decoder.init_hidden()
    prime_input = char_tensor(prime_str)
    predicted = prime_str

    # Use priming string to "build up" hidden state
    for p in range(len(prime_str) - 1):
        _, hidden = decoder(prime_input[p], hidden)
    inp = prime_input[-1]
    
    for p in range(predict_len):
        output, hidden = decoder(inp, hidden)
        
        # Sample from the network as a multinomial distribution
        output_dist = output.data.view(-1).div(temperature).exp()
        top_i = torch.multinomial(output_dist, 1)[0]
        
        # Add predicted character to string and use as next input
        predicted_char = all_characters[top_i]
        predicted += predicted_char
        inp = char_tensor(predicted_char)

    return predicted

# %% [markdown]
# # Training

# %% [markdown]
# A helper to print the amount of time passed:

# %%
import time, math

def time_since(since):
    s = time.time() - since
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)

# %% [markdown]
# The main training function

# %%
def train(inp, target):
    hidden = decoder.init_hidden()
    decoder.zero_grad()
    loss = 0

    for c in range(chunk_len):
        output, hidden = decoder(inp[c], hidden)
        loss += criterion(output, target[c].unsqueeze(0))

    loss.backward()
    decoder_optimizer.step()

    return loss.data.item() / chunk_len

# %% [markdown]
# Then we define the training parameters, instantiate the model, and start training:

# %%
n_epochs = 4000
print_every = 200
plot_every = 10
hidden_size = 100
n_layers = 2
lr = 0.005

decoder = RNN(n_characters, hidden_size, n_characters, n_layers)
decoder_optimizer = torch.optim.Adam(decoder.parameters(), lr=lr)
criterion = nn.CrossEntropyLoss()

start = time.time()
all_losses = []
loss_avg = 0

for epoch in range(1, n_epochs + 1):
    loss = train(*random_training_set())       
    loss_avg += loss

    if epoch % print_every == 0:
        print('[%s (%d %d%%) %.4f]' % (time_since(start), epoch, epoch / n_epochs * 100, loss))
        print(evaluate('Th', 99), '\n')

    if epoch % plot_every == 0:
        all_losses.append(loss_avg / plot_every)
        loss_avg = 0
# Out:
#  18s (200 5%) 1.9216]
# Thecle jorth the all are ang this.
#
#
#
#
# Ant noghreinter .Fiolds seritys.
#
# The.
#  Angseg waes oot
#
#  38s (400 10%) 1.9116]
# The whirare dorens,
# And mons, the the Gher the warelt the God God ands frore.
#
#
# 	For worls resdere b
#
#  58s (600 15%) 1.8146]
# The mevantinot saby rater proom of of has the sadporressies appouristrmstans, as nom herserfist of un
#
#  18s (800 20%) 1.5141]
# The the paterice ore Gyou he souls. the mind these vivive entellisess with the giole a eaming alle vh
#
#  38s (1000 25%) 1.3434]
# The Ments the Father
# And which from one are porth, and giving the ening with the you or they gathengi
#
#  58s (1200 30%) 1.3123]
# The Father in the hersul in the entrable incled not the mortine if as works progress in koong stentre
#
#  18s (1400 35%) 1.4621]
# This ceernal-perfentind into the earrry ever requal God, as which is it which with respurry world;
# Or
#
#  37s (1600 40%) 1.4595]
# Ther splentralle imecore entrued a she a cliked to be triads.
#
#
# 	Intelligible, and because of the
#
#  56s (1800 45%) 1.1268]
# The contain, a secause containce of understand of the Intelligible, the Intellect
# Of all that atuatai
#
#  14s (2000 50%) 1.5939]
# The father.
#
# 	The cavensert beceing the have the gave hemace, the sead taimes soul, and and evere al
#
#  33s (2200 55%) 1.2539]
# The are are call accord the stor world for has the depth of his mow.
#
#
# 	Meal incure firsleds as h
#
#  53s (2400 60%) 1.5605]
# The strength: be descesting are of the Father paternal esee the which soul soul, and to the bavent of
#
#  12s (2600 65%) 1.7285]
# The cen the etep of the ether: for is the Father parts of Hecate the Fired mind the more of whence.
#
#
#  31s (2800 70%) 1.4275]
# Theught, of matter this father assert iniver three.
#
#
# 	The Mind throung pure, and pouse.
#
#
# 	All
#
#  50s (3000 75%) 1.0430]
# The soul the Father rid in the shou onorce in the sun of ore when the worlds of the world, sits, and
#
#  10s (3200 80%) 1.2574]
# They asserts virted the Father works above the placed whom man, and with many night
# Of the whole work
#
#  29s (3400 85%) 1.2069]
# They are mormate bortend and wil one conceredtain of.
#
#
# 	By they are prodide of the Father
#
#  48s (3600 90%) 1.1588]
# They are the minglelentele, and the souls, which."
#
#
# 	The generations of be strength.
#
#
# 	F
#
#  7s (3800 95%) 1.5632]
# Through the airives rulessed asterstablitions, bate, and are signtenane sappring flashings of the pri
#
#  26s (4000 100%) 0.9681]
# The Spirication of the Father, and of the eather, and them and world that stars the inlectars of a co

# %% [markdown]
# # Plotting the Training Losses
#
# Plotting the historical loss from all_losses shows the network learning:

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
# %matplotlib inline

plt.figure()
plt.plot(all_losses)

# %% [markdown]
# # Evaluating at different "temperatures"
#
# In the `evaluate` function above, every time a prediction is made the outputs are divided by the "temperature" argument passed. Using a higher number makes all actions more equally likely, and thus gives us "more random" outputs. Using a lower value (less than 1) makes high probabilities contribute more. As we turn the temperature towards zero we are choosing only the most likely outputs.
#
# We can see the effects of this by adjusting the `temperature` argument.

# %%
print(evaluate('Th', 200, temperature=0.8))
# Out:
# The vilk, and are direction,
# Tha' yound Mlind and the abounding andings will not sending of the mays ""fiem.
#
#
# 	For the maters are not lead are mortal soul,
# But the vile of great evengly of th

# %% [markdown]
# Lower temperatures are less varied, choosing only the more probable outputs:

# %%
print(evaluate('Th', 200, temperature=0.2))
# Out:
# The Soul in the sun and the soul in the soul and the sevent of the Father, for the soul send the angent of the and the Father and the Father, or has the and the moon for he aquated in the and the world,

# %% [markdown]
# Higher temperatures more varied, choosing less probable outputs:

# %%
print(evaluate('Th', 200, temperature=1.4))
# Out:
# Thouding notled of is fatate.
#
#
# Fnay mire, subs brauternie.
#
#
# 	. For
# Bo the firmausion call, being nolect thinke in all,
# The, corperveffaring riserve-mlectiechs
# Of apceernderding think, gonlnd

# %%
print(evaluate('Th', 200, temperature= .3))
# Out:
# The fire in the licter spirit of the and the moon for he aquatic spiring the progeny of the sevent to Zoroaster, who the mortal send the fountain of the soul soul sacred souls the sun) in the soul sacre

# %%
print(evaluate('Fa', 400, temperature= .20000005))
# Out:
# Father in the sun and of the Father and the fire, and the Father concers, which cond the Father,
# Reging the intain of the Father, or he pare concers of the soul in the fire, and the Father sun, and the and of the Father in the and the mind.
#
#
# 	For the mind in the mind in the lich concer of the angent of the world, and the mind the mind in the sun and the great spirit, who the moon of the Father an

# %%
print(evaluate('Ma', 400, temperature= .20000005))
# Out:
# Master of the Father and the world, and the world, and the mind.
#
#
# 	For the mind the mind in the mind send the Father and the mind in the sun and of the mind in the mind the mind the mind in the mind the mind the mind the mind the world, and the world, as the sun and the world, and the mind in the mind in the soul send the Father spirits of the mind the mind in the mind in the sun and the mortal

# %%
import numpy as np
for i in np.arange(.2, 1.5, .05):
    print(i)
    print(evaluate('Ma', 400, temperature= i))
    print("********************************")
# Out:
# 0.2
# Master in the are concerth the soul soul in the aquated the mind,
# He Soul derive the mind in the aquated in the world, and the world, and the mind.
#
# ********************************
# 0.20500000000000002
# Master in the mortal world, and the fountain of the aquated.
#
#
# 	Lovely the about the fire in the intaries of the and the mortal splend the soul in the sun, and the soul in the soul in the aquated.
#
#
# 	Learn the are concurital in the aquated in the mortal of the angent of the anercur,
# That the mind the mind the mind in the and the mater of the aquated in the aquated.
#
#
# 	Lovely and the mind in th
# ********************************
# 0.21000000000000002
# Master of the Father, for the aquated in the world, and the lich concessend in the sun) in the seven a concesses of the and the aquated in the fire, and the sun and the moon of the soul soul send the world, and the world, and the world, and the world of the aquated in the world, and the world of the aquated in the world, and the sun and the mortal world, and the intermater, and the world, and the aq
# ********************************
# 0.21500000000000002
# Master world, and the aquated in the are concerth the about the soul in the soul in the intains and the world, and the aqual things and the mind.
#
#
# 	For the mater of the and the mind the mind in the and the mortal world of the mind the Father,
# The Soul and the world, and the mind.
#
#
# 	For t
# ********************************
# 0.22000000000000003
# Master of the Father and the world, and the earther world, and the aquated in the fire, and the Father, for the world, and the aquated the intermation of the sun and the sun and of the and the world of the soul will in the mind the mind the world, and the sun and the mind.
#
#
# 	For the mind the sun and pone of the mind in the mind in the world, and the mind the mortal world.
#
#
# 	For the angent of
# ********************************
# 0.22500000000000003
# Master of the and the mind the Father, or For the sun and in the sun in the mind.
#
#
# 	For the great sun and the mortal world changents of the sun, and the sun and in the mortal sphilon the mind the mind the intaried of the mind the sun.
#
#
# 	For the mind the may and the mind the world, and the mind,
# He Soul in the mind the mind the sun and the mortal world, and the world, and the mind the mind the m
# ********************************
# 0.23000000000000004
# Master world, and the soul souls the aquated.
#
#
# 	Learn the are progeny of the anerch mind.
#
#
# 	For the sun and the intermation,
# The Mind the sun and of the manner not the mind of the soul see the mind the mind.
#
#
# ********************************
# 0.23500000000000004
# Master nourses the mortal world the mortal world, and the oracle, and the aquated.
#
#
# 	Learn the world of the and the Father in the mind.
#
#
# 	For the mind the mind the mind the Father and the mind,
# But the mind in the Mind in the mind in the mind the world, and the mind.
#
# ********************************
# 0.24000000000000005
# Master concerth the are concerth the fire in the world, and the aquatic subsistances will not spirit, and the mind.
#
#
# 	For the angent of the aquated.
#
#
# 	Learn the mind in the mind the may and the mind the mind in the mind the mind of the sun, and the mortal world and the mortal sphird of the mind in the sun, and the mind.
#
#
# 	For the angent of the
# ********************************
# 0.24500000000000005
# Master world, and the aquatic spirit or of a concer of the paternal voldion of the aquated in the intaried of the soul in the world of the aquated the moon for the aquatic sending the moon, and the fountain of the are concers of the mortal world as the intaring will nature.
#
# ********************************
# 0.25000000000000006
# Master concer of the and the Father, for the carates of the Father and the soul world of the aquated in the sun the moon of the sun and the sun, and the world, and the mind.
#
#
# 	For the great sun and the world, as the fountain of the Father concers.
#
# ********************************
# 0.25500000000000006
# Master of the earth, and the sevent to the world, and the aquatic loodies of the sun in the soul sacred spirit of the sevent the world, and the aquated in the fire in the soul in the soul in the aquated in the world, and the world, and the seven the mind.
#
#
# 	For the mind the mind in the mind the mind in the mind the mind in the mortal of the mind the Father world, and the mind the world of the sun
# ********************************
# 0.26000000000000006
# Mast of the aquated.
#
#
# 	For the sun and the fire the mind the great spiring to of the Father and the pole of the Father, for the Father, or he gods the soul send the Father in the internal concesses of the world, and the alonate of the Father in the soul soul send the world of the seven the mind in the anercur of the mind in the Father world, and the mind in the goddes the light-zower of the soul
# ********************************
# 0.26500000000000007
# Master not subsistances of the lich concerth of the Father, for the aquatic sacred for the Father in the soul sacred subsisting the Father-the Father-the fire.
#
# He fountain the lich concesses of the anercurith, according the world, and the soul the world, as the world, and the intall fountain of the Father in the soul in the soul send the mind in the mind in the ascent with the soul sacred for the s
# ********************************
# 0.2700000000000001
# Master of the mind in the mind in the lich concesting in the oracle.
#
#
# 	For the mind the paternal from the mind the Father in the sun and the world of godden.
#
#
# ********************************
# 0.2750000000000001
# Mast the inerces of the world, and the mind.
#
#
# 	We and the mind in the mind in the aqual conceing the mind the aquated in the world, and the world, and the sending the intermation,
# That shine a concersible and the aqual things in the oracle concers, and the world, and the aquatic all things in the empyrears of the aquatic stabliging and the Father-begother in the soul sacred for the aquated the fi
# ********************************
# 0.2800000000000001
# Master nourses the mind in the intermation of the world, and the aquated.
#
#
# 	Learn the mind in the great sun and in the world, as spiral form.
#
#
# 	For the sun and the sun, and the empyrean world,
# And the mind the mind in the manner noner nature concesses of the world, as the great spiring will nature.
#
#
# 	For the mind the mind the angent of the mind the mind the Father and the mind the
# ********************************
# 0.2850000000000001
# Master in this the sun, and of the seven the Father and the sun.
#
#
# 	For the mind in the sun are conces the mind in the world of generation of the immater, and the mortal world the mind the mortal spherear world, and the mate the Father concers of the are contain of the world of goddes the sun, and the world, as the world, and the mind.
#
#
# 	The Mind spirits the aquatic sphist will nature a conce
# ********************************
# 0.2900000000000001
# Master of the searth the mind.
#
#
# 	For the mind the mind the paternal which a concersible conceive the mortal spiring the fire in the apparent the oracle of the Father, or soul send the Father in the world of the soul serve the Father, for a conces the mind the mind the mind the soul soul see the great spe of the mind in the aquated
# Those in the mind the mult the whole principle will nature in the
# ********************************
# 0.2950000000000001
# Master concer of the air, and the apparent concerth the world, and the oracle corrounds all things in the soul sacred for the inerces of the oracle.
#
#
# 	For the Father of the anercur,
# That spirits of the soul send the Father send the mind in the sun and of the world, and the sun, and the sun, and the mortal world of the sun, and the mortal splend se
# ********************************
# 0.3000000000000001
# Master concerth the pole of the licter, and the fire, the Father, or he progoudes of the world, and the intermater, and the mind.
#
#
# 	For the mind in the mind the whole principles the Intelligible fire in the Father in the lictor fire, which the pare conceine of the world, as the instand in the great she progeny of the Fath
# ********************************
# 0.3050000000000001
# Master the mortal concessen the world of the Father in the sun the licter,
# Remselfible for the sun and of the aquated in the intermater, which shine concental world.
#
#
# 	For the whole vire concers of the mind the sun in the sun, and the soul send the aquated in the mortal of the aquated in the mind.
#
#
# 	For the light of a concerth of the soul,
# But the soul in the soul in the aquatic spiral
# ********************************
# 0.3100000000000001
# Master and the mortal world and souls the world, and the mind.
#
#
# 	For the mind the mind in the mind of the mind the mind world.
#
#
# 	For the mind in the sun and the mortal world, and the mind.
#
#
# 	For the whole concers, which concers, and the sun, th
# ********************************
# 0.3150000000000001
# Master of the world sphald,
# And the world of the world of a concers, and the mind.
#
#
# 	We and the paternal from the mortal world course life world, and the maters of the mind, and the world of the aqual send the world, and the world, as the apparent concersible forth the paried will nature a concers of the anor sacred mind the Father, and the sun) in the soul sacred, for his concuring the world, a
# ********************************
# 0.3200000000000001
# Master like world.
#
#
# 	For the angent of the world, as the soul in the seven the mortal world, and the world of the mind the Father and of the mind the poles of the intermater, or soul see as the world, and the world, and the mortal world.
#
# 	For the mind in the sun and of the sun and sun as the soul send manner nature world of the world, and the fountains of the intaring soul serve the Father,
# R
# ********************************
# 0.3250000000000001
# Master nature, and the soul world, as the mortal world.
#
#
# 	For the progress of the sevent to the soul in the soul send the fire in the Father and the great sun and the sevent of the and the Father, or he may of the paternal fountain of the Father and the mortal mind of the mind the great sun the fountain of the mind the mind simmine a concers, who the world of the sun, and the soul soul seration o
# ********************************
# 0.3300000000000001
# Mabing the voice in the fountain of the maters the materself, and the aquated.
#
#
# 	Lovely the form of the soul see the are concers will nature.
#
# 	Learn the like a concer of the empyrean of the anercuring a concer of the oracles of the soul-spirit of the oracle.
#
#
# 	Which concers of the aquated in the soul in the sun, and the moon, and the aquated.
#
#
# 	For the Father convex f
# ********************************
# 0.33500000000000013
# Master in the aquatic concerth the paternal world of a concers, and the fire, and the world of the lich concelised of the and all the Father and the sun) in the aquatic world,
# Cirnitated the purished will the sun and progoucus conces in the mind, and the world, and the sun) is not subsistances of the sun.
#
#
# 	For the Soul in the aquatic conces the mind in the great shall souls the soul light forth
# ********************************
# 0.34000000000000014
# Mast slection, and the sun and the world as the world, as the mind.
#
# 	Wholly vircurn and the and the mind.
#
#
# 	We like a concers of the aquated.
#
#
# 	Learn the mind the mind in the mind in the mortal not will the mind in the mind the light of a concers, and the aquated in the aquatic spiring the oracle.
#
# ********************************
# 0.34500000000000014
# Master sending the Father, for his of the Soul in the aquated the intarion, and the mind.
#
#
# 	Selove the intermater of the lictor of the and the Father, or hower of a course of the oracle.
#
#
# 	The Soul a correal concesses of the soul in the mortals of the anermaten the world, and the sun.
#
#
# 	For the Father and the fire send the Father in the sun of the Father and the moon of the mind in the
# ********************************
# 0.35000000000000014
# Master of the earth;
# The paternal fountal the Mind in the apparent the mind the angermation of a condine is the warth the begortal fountains and the aquatic sacred mind.
#
#
# 	For the stars of the are concers, when the pole of the intaring will things the Father in the sun, and the soul send the intarie, and the
# ********************************
# 0.35500000000000015
# Mast material, and the leades will the intall of the world of the Father world, and the mater will the world, and the mind in the mind.
#
#
# 	For the mind of the anercur,
# The Soul light for the sun, the mind in the sun and Eartar of the world as the great spiring in the moon of the angent of the Father concer
# For the lease for or the soul in the mortal of the angenternal from the oracles and the inte
# ********************************
# 0.36000000000000015
# Master world, and the licter, and the sun the and the mind, and the mortal of the aquated.
#
#
# 	Learn the mind the fire him the bring from the Father, or becomes of the sun.
#
#
# 	For him the Father concers of the sun and promes of the and the world, according to the soul in the sevent of the the mortal summing to conces of the sun and the empyreal form the oracle of the soul in the sevent of the Fath
# ********************************
# 0.36500000000000016
# Master of the aquatic sending the Father, for the are conceptarned and the soul section, and the generable concesses of the world, and the soul world, and the Mind, and the mundane conces of the an the Father conding to Zortar.
#
#
# 	For the pare for he and the lich cond of the angenter, for or the world as the soul sun
# ********************************
# 0.37000000000000016
# Master in the sun, according to Zortar of the world, and the aquated.
#
#
# 	For the mind the minds and the mortal concepth of the Father and the fire, and the great of the soul soul send the world, and the great sun the mind of the sun and pone of the mind.
#
#
# 	Evil the fountain of the sun, and the mind in the world, and the intermation of the world of goddends.
#
#
# 	For the aquated in and th
# ********************************
# 0.37500000000000017
# Master concerth not the aboundane spiring the souls alond the aquatic sacred the fountal stand of a concentined in the aquatic some a the world, according to the soul in the fountain of the world of the aquated in the world, and the aquatic sending the Father and the sun and of the fire, the world, and the worlds of the sun.
#
#
# For the sun and the intermated of the Father conceive of the Father c
# ********************************
# 0.38000000000000017
# Master of the sun and of the apparear for hird of the may of the and the whole of the Father,
# The proguching forth correal course forth the aquated in the air spectane vire in the angels of the aquated.
#
#
# 	Having mank the moon fire in the mortal world the aquated.
#
#
# 	Lovely the park of the mortal world.
#
# 	We the sun and the world, and the aquated the moon for the world, as the abounding the ins
# ********************************
# 0.3850000000000002
# Mast silence in the world of the world, according the soul all-Eartal of the soul sending the fire sark of the world of the aquated the oracle.
#
#
# 	For the Intelligible in the first in this the intars of the Father-coles of the sun the earth of the Father
# The Soul in the mind is
# ********************************
# 0.3900000000000002
# Master nature a sending the concerth the world, and the aquated.
#
#
# 	For the eternal sphilon the sun and of the lich concerth of a conceine of the intarie of the licter, and the earth.
#
# 	For the mind in the mind in the inergater world of the empyrear nature.
#
#
# The mind the may not spiring the great the soul in the oracles a concers, and the Father, or he internal concessite concerth in the moo
# ********************************
# 0.3950000000000002
# Master sits the world, and the aquated the apparent concerth in the mortal concerses of the earther of a conces world, and the mortal of the soul in the soul in the light forth the aquated thinks and the seaven the Father, for the Father and the sun, and the Father, for the world has the appear,
# Rerations of the and of the Father who the world, and the sun, and the Intelligible in incorrate.
#
#
# 	Ha
# ********************************
# 0.4000000000000002
# Mast of the souls of the paternal form of the and eastances of the fire.
#
#
# For the world of the certains of the world, and the world, as concers of the soul serve in the mind which conding to the fire, and the world, as a course in the world of the Father, or will nature.
#
#
# 	Learn the sun the gring of the empyreal vire of a course light of the Father, or he as the poles of the world, according
# ********************************
# 0.4050000000000002
# Master concersistents of the air, and the world, and are conceive the fire, and the world as the mind, and the whole assen the and and subsistancess and of the aquatic subsistances will name the mortal concers of the sun.
#
#
# 	For the lich conceir concers of the assimilate to the ineratic spegent of the mind.
#
#
# 	Wholly and subsisten mind is for you seending the Father concures of the oracle course l
# ********************************
# 0.4100000000000002
# Mast world of the world of fire the soul dision,
# The Father of the mortal concesses world,
# S old the world, and the aquatic sending the world, and the mind.
#
#
# 	For the sun of the Father in the moon for the sun, and the mind in the soul says of the sun in the sun aronad sending the Father, or he instilar spirit of a concers.
#
#
# 	Evilligible in the oracle for the sun and the loud of the loul-spland
# ********************************
# 0.4150000000000002
# Master of the world, and with the aquated;
# That the sun and the oracles, and the world, and the mind.
#
#
# 	For the principle in the mortal concers of the mind of the empyrean concers, which course like concers.
#
#
# 	Thence a cloul will things the musces of the stars of the soul in the world of the aquated the park of the Father
# And things are concesses
# ********************************
# 0.4200000000000002
# Master of the aquatic goddes not the oracle, and the Father world, and the aquated in the certains world of the sevent of the anemsel
# Becomes of the world, as the world, as the Soul, according the oracle.
#
#
# 	For the beghint of the soul splence in the soul send the Father, the Father, and the sun, and the generad in the fountain of the sun, and good the God, and the mind and t
# ********************************
# 0.4250000000000002
# Master whirl selfe concers.
#
#
# 	For the Soul in the first subsistances of the angentled the mortal world and will the measure nature.
#
#
# 	Learn the mind in the asce of the mind, not in the earth of you in the great sun the mind.
#
#
# 	Tho' you manner, which condine to becomes by this the licter, which sending the Father, and the Father
# And the soul in the Father and progoun counse of the F
# ********************************
# 0.4300000000000002
# Master of spirition,
# That seent to the sun in the sun and poles of the Father in the world the world of the Mind of the mind.
#
#
# 	For the Soul a concentains and partions, or the lich concesses of the world, and the mortal will of the mortal spending not the oracle,
# The mortal spherear of the world, as the world souls of the Father, or not speart of the soul in the intains of the a
# ********************************
# 0.4350000000000002
# Master of the oracle.
#
#
# 	And the fire in the Father for the intarning all totic somes will in the licate course a concers.
#
#
# 	The progovern the may spirity, and the mind.
#
#
# 	We your sacred spring and the world, and the soul sacred sension, or the sun the fountal corrounders, and the aquated
# Thorne
# ********************************
# 0.4400000000000002
# Manner cones the sun) in the ascears of the Father discourse not sun for the oracle for his of the soul soul soul for the into the world of the world, and the understanding will noment will in the whole concuryses, and the sun.
#
#
# 	For the minds the mind in the lich conces by the gods of the world as the mind in the soul in the Father, or he pure of a clourse of the sun.
#
#
# 	For three varing the
# ********************************
# 0.44500000000000023
# Master world.
#
#
# 	What the Mind in the mind in the firmulit of the aqual things and the soul in the aquatic sumbird the Father
# And correal forth the world of mind in the world, and mind.
#
#
# 	For the whole vision the fountain of the Father-the soul soul cond the poles of the soul light for he instand the images of the Father-the fire.
#
# He fountain the Intelligible in the sun and the world, and
# ********************************
# 0.45000000000000023
# Mashings the oracle,
# The fountain the aquated the fire, and the fire, the mind in the Father in the Father and progounds of the paternal venerable forth the mind in the lich concersable of the mundar of a correms of the aquated
# Through of Hecate not course them and the mind the oracles.
#
#
# 	The Soul all-splection, and the separated of the sun) in the paternal fountal concers.
#
#
# ********************************
# 0.45500000000000024
# Mastic subsistances will the lich correal concesses of the sun.
#
#
# 	For the mind in the are congregial sphird in the sun and the mortal which concers, who the mater abound the alonable send the Father, or he world, and the fountain of the angenter,
# Remable in the world soul manner,
# For the sun, and the mortal world he oracle for the world send and the sun
#
#
# 	For the manner nature in the goddess of
# ********************************
# 0.46000000000000024
# Master with the moon,
# Rering all things in the sun according to the Hecate;
# They as this the vilk, according the power
# Of the aquated.
#
#
# 	Lear a concelies of the paternal fountain and the Father, and the aquatic conceers: the world, as the Father, or he may of the are conces of the anon of the leade earth, and the Father of gods this) the lich a concesse of the ethere the loous of the anercurine.
#
# ********************************
# 0.46500000000000025
# Master concection of the world, and the disponding soul in the oracle for the world a corresporears of the aqual concestic shall sending and the lich concesses of a concer of the world, and the world, according to Zoroaster, and the mind, and the mortal world the are cond of the mate a coned the sun) it in the abounding the loouse of the aquated in the Soul of the aquated.
#
#
# 	For the ground in the
# ********************************
# 0.47000000000000025
# Mast of the and the Father and of a course, power of the plane Mind.
#
#
# 	Heaving the world of the sun and the generable fountal which concestic sending the fountain of the fire send the an the anercurine of the mane in the Father of the inates world, as the anot will of the Father and the intermate of the sun are fountains of the angent of the mind to the aquatic light in this, and earth, and the i
# ********************************
# 0.47500000000000026
# Mable a course life world the empyrean, and proceentinanten all things in the mortal world, as the Father-the goddes of the world, and the world, and the concermaned things the mind.
#
#
# 	For the life fountain of the angending in the lich concessen to the body of the and the progeny of the licter soul light of the venerable for the world, and the vestances.
#
# ********************************
# 0.48000000000000026
# Master
# The oracle collectaine fountain of the apparent corporar concesses the world of the soul like world.
#
#
# 	For Erthers and the world, as the licter, and the fire and the world, and spirit, according to the aspeart on the moon of the alonate spiring in the earth of the sevent to Zortar.
#
#
# For the angent of the Father, or not will the world, and the apparent of the menderser
# ********************************
# 0.48500000000000026
# Mast in the intermation,
# But the world, as the mind.
#
# 	Even the sun and the mind of the and mind, and the world, who the may oun the great sun in the loud to understaming subsistances,
# Mind in the paternal of the world, according to the world of the Father, for the Mind in a corrual may soul discourse the ventraming to the aquatic seven the partain of a concestinect of the aquated
# He body of the s
# ********************************
# 0.49000000000000027
# Manted in the sun and the world and the sun.
#
#
# For the sun and the soul sacred fire, by the whole virdion,
# That all things the voades concers of the ethere and of the mortal world stars of his concuring the aquated in the world of the seaven the mind.
#
#
# For the agenal spirits of the aquated with the lick Soul dortal world and the licter in the aqual summing to corporeal in the mortal formustic sp
# ********************************
# 0.4950000000000003
# Master eneration, and the empyrearing and of the and in the soul in the oracle, according to Zoroaster, and the according to the soul in the fire, and of the licter, and the mortal of the light-croodes of the aquated in the leade of the corries, and the sun, or the vilk,
# For the great which goddent the carries of the Father,
# Rerve the mortal stars of the lich, according all the Soul in the oracle co
# ********************************
# 0.5000000000000002
# Master cond of the intermate lead,
# For the sun, and summing light forth oroaches of the sevent of a conces of the sun, as the air,
# And the apparent progone forth the mind.
#
#
# 	For the life channels the whole vire in the mird the lich concers, recing the aquated in the sun, the soul in the anor subsistances of the inable light moon, and the mortal of the and to body,
# The Father life for the mind thi
# ********************************
# 0.5050000000000003
# Master nou a spirit, and the fire in the Challs old of the internal spirited a concersibing form of the mind.
#
#
# 	For the intall in the all-blour sing of the seven the progenyoned the lich concer of the earther splendid, and the Father in the tellectual concessity.
#
#
# 	For the mind in the empyreal of the world the oracle.
#
#
# 	The great sun mink nour of the empyrea
# ********************************
# 0.5100000000000002
# Master work of the soul sacred stars which in the carks.
#
#
# 	For the mater of the angent of the and the which the fountain of the loud the oracle.
#
#
# 	Sark in the whole olles will of the intellectual concention, and the oracle, the oracle,
# The inefrace of the moon, the sun in the sevent the mind.
#
#
# 	For the mind the world of the much manner, which concentiny are connecter, by the lich o
# ********************************
# 0.5150000000000003
# Master are conces of the and the mortal sphist about the aquatic is will name strength, and the world, and in the aquated in the mind.
#
#
# 	For the mind the firme of the sun and the moon for or resending the licter, and the world, and the fire in the mortal send he oracles conceive of the mind who stars of the sun as the empyreal form a spiring will not the proges not with sendence the mind in the w
# ********************************
# 0.5200000000000002
# Master of the Father-begote or of a conces the whole of the lich, according the earthorth another sught the Father was ming collectic sending the Father, for the oracle, the fountain of the Father in the Father-the God, and provending concer, and a the paried of the soul soul see the aboounders, and three voiders or of the searth fire, the Father, for the Soul soulders of the venerable renar works o
# ********************************
# 0.5250000000000004
# Master of the concesses of the soul in the imate of the called in a correal poles a clour own conces of the apparent concersible.
#
#
# For the Father, or Mind of a concersing and the soul in the assing and the aventor having carres the fire, the world, who fire in the aquatic spiring will in the Switligible for in the sun the sun) ((into the oracles, through the souls the oracle, and the sacred, th
# ********************************
# 0.5300000000000002
# Mast in the soul soul light in the fire,
# And the an appear forth a the paried of the alonging all the sun, the sun), and proone of the mortal infelicts will and the understanding world, and the alonding world, and the pole of the aquatic mind the world, and the first.
#
# For the fire in carrirstrated the poldions of the aquatic sich the moon, and the wills of the mind are remore seing forth the oracle
# ********************************
# 0.5350000000000004
# Mastenses in the soul sacred mind, and the soul separated the soul in the lich conceliges.
#
#
# 	Which the sun, and the are collectic of mead of the sun, all this sun.
#
#
# 	Havink the alonce in the insludies of the soul-spole world, and the inerger mind.
#
# 	Having mind the mind the mind in the call the preserved fire the instanding from the aquatic subsistances world,
# And the paternal forth
# ********************************
# 0.5400000000000003
# Mastic stars of the sun, ethe more of the world, and the mind, as a carming the soul totitual solar forth of the soul moon.
#
# He Mind the mind the intall fountains and the Father calls things above the moon,
# For the sun and a serve of the Father,
# Rence a confething the oracle for the empyreals of the anor poles of the paternal fountain of the instands.
#
#
# For the sun and mortal world of the mate the
# ********************************
# 0.5450000000000004
# Mast line eastrent with the paternal fountal nature rules a conding all things of the intane of fire.
#
#
# 	Measten the lich conces of the are mind,
# For the fountaing of the Father, or shaming will, but thinks, and the forth that who thish the generary Soul in the mind serning all those of the Father, and the leasuses and the oracle,
# The aquated thinks of the generar of a certain of the alonable seri
# ********************************
# 0.5500000000000003
# Mastic sept the pous of the world, and the world, and the aquated the power of the mind,
# He for he anercurn the may send not world.
#
#
# 	For a the fountal concer oracle, and the sun, soul lead in the fire.
#
#
# 	Femy vewill the mind in the mind in the mind in the sun and more a concers: the soul remain the aqual manner.
#
#
# For the Soul may underspring connecterial, and the mortal s
# ********************************
# 0.5550000000000004
# Mable contain in the fire in the aquated.
#
# 	Even a sacrersen to the lich all to the oracle, and the soul the aquatic understanding will sending all things to the aquals not the knodse life-bolls.
#
#
# 	Exellespond in the like as the soul the instands of the soul in our in the loul fountal some ortal ware the mistrencip and the manner contal spround, and the world.
#
#
# 	Leal fountains a
# ********************************
# 0.5600000000000003
# Mablars, wectual strengthercent of the Mind in the sun.
#
# 	Energht the sun, and pronouces of a certain of the sun in a the one fire seection, and more conceers.
#
#
# 	Evily the mortal world, and the gart of the empyrear.
#
#
# 	For the mind the body of the cause of the soul in the world, and the intermation of the gods the earth infel.
#
#
# 	Tholle concuring the generable a concestiny and sinding wit
# ********************************
# 0.5650000000000004
# Master of a concer of the world, according to the oracle,
# The oracles conceirsital Soul infelich the Soul world, and the aquated.
#
#
# 	Lovely the browing from the anercur-noure condition.
#
#
# For the soul in the first reperial, and the oracle concestined the Father,
# The Father of the empyreal forth the fire is for the Soul dording to Zoroace the soul will Trame of the mind.
#
#
# 	For the sun in
# ********************************
# 0.5700000000000003
# Master who the moon forth of a concerth of the aquated you see of the soul, which conding to Zoroaster, and the world his own the aquated;
# That the intaring all the soul inform of the vemernar,
# And the intars the intarnion fort for here of a certane sending the pare concer in the paternal vend of a course, and the paternal flower who sun.
#
#
# 	For the wholly and the mind in the sun and is a celearm
# ********************************
# 0.5750000000000004
# Maspirity becomes as the sun, and the form of the aquated.
#
# 	When the licter form above himself.
#
#
# 	For the progre of Hecate concessen the depternal fountain and the soul soul forther in the Father and of a coned the world alonce to concerth of govern the empyrear manner and the begord of the world of the world of the soles of the sun and the loon of the mortal world, and works the inerces, an
# ********************************
# 0.5800000000000003
# Mast they are aloncus
# He progres of the anercur,
# The Soul in the sun are worlds, according to Zoroaster of a conding to bodies the Father,
#
#
# 	Sarcure of the world, the mind.
#
#
# 	For a conces to the mirding eartal sphiloson the instill of the lich of the aquated.
#
#
# 	Love of gerearnend, and the fire, and the Father world, which in the world, according to Zoroas of the Father,
# Regind of the
# ********************************
# 0.5850000000000004
# Manumes of the eare loonad infestic sending the dispion,
# The Soul of the earth;
# The mind in the mater of a corrounds olfor mender.
#
#
# 	Lorreal forth the generar fountain of the mortal worlds.
#
# 	When the mater progressing the oracle course, according the fire in the aquated with manner with Heaven, End with Intellectual dish mortal world.
#
#
# 	For the known in the angent of the Father,
# And the Fat
# ********************************
# 0.5900000000000003
# Master the sevent the paternal from the sun, and in the moon, and the sun in the moon, and the world, and the world, according to Zoroaster subsistances and the Father-the about forth things fountain.
#
#
# 	For the pare concentize life-poreive of the are a cottending the empyreaven a to the misk (of the mind.
#
#
# 	For the concurnal from spiral fountain and the Father, or not stable conc
# ********************************
# 0.5950000000000004
# Mate to collectic splendid.
#
#
# 	For The aral the paried the paternal fountain through the soul soul serve and the sun in the fire subsistance of the world, according to the soul see corrial, which in the Father send the angent of the to the Father-begotten the anercomec rules were in the Father, and the Father-per abounding they are lictor of contains of the anding from the world of the sun,
# ********************************
# 0.6000000000000003
# Mast subsistane in the world a cloundains, and theree as the moon from the sun.
#
# 	For the licter, for he and the mind the adce concers and the inergated.
#
#
# 	Learn the ascence the great forth that of the world splend in the Soul sendlagence.
#
#
# 	For the sun arrion of the world, and thinks.
#
#
# 	Fe the paternal the whole vast the fountal speartand of a sension, the and of cirecclurition, are conce
# ********************************
# 0.6050000000000004
# Master conjoon of the Father conceres all things the oracle eternal, for you soul sacred mortal concesse
# The whole of the lich of the Father, as aquated.
#
#
# 	Love, the lich coners of the aboundains, or the godde of the calles appear of the empyrearing concerrent to the empereal vision,
# The firxe, or the instanders, and the moon, and the parpounds all things in in the world of the eartal soul soul r
# ********************************
# 0.6100000000000003
# Mastic speirs, and the sun.
#
#
# 	For the oracle it the oracle in the to eration, and the mortal descomplese of the Father of the intermated the mind,
# He Spirible run you a corresting the fire and somes of the sun of the soul the sacred in sphilonds of the sun.
#
#
# 	For the Soul sing figh the gods the instand in the sun and in the is aplared in the Ming to the gady the sun
# Ear of the soul sacred f
# ********************************
# 0.6150000000000004
# Mater, and the intermation of the world and of the mortal wind the aboundays of the seasonfed in the centre of gelower the world, and the intellectual, and are may of the inlanmenting, and the aqual course.
#
#
# 	Wholly virmion,
# But for younds the empyrean of as called and the Souring to olfor of the ruless of the seven the paracle,
# Having all things mind in the aquatic subsisten manner undersprinate,
# ********************************
# 0.6200000000000003
# Master nounding the run coudinacle.
#
#
# 	For the internal send mild the Intelligible sawing the fire in the Father in the fountain of the sun to call, as hound is a concesses with in the sun, fort will things in the aquatic links to the intworld the cond the Father in the whole Mind.
#
#
# 	Learn which in the plant in the learmour of the Father and recond.
#
#
# 	For the Mhanner in the whole Intellect
# ********************************
# 0.6250000000000004
# Master
# Sunwarxing mortal world.
#
# 	The Soul derive of the Father and the vich incoure course like morre nature.
#
#
# 	For the sun and the Father, and a the moon of the Father and the mind the fountal connected.
#
#
# 	For the fountain of spiring forth to himself,5 a certain of the Father
# Hear of the Sousion, and the soul sendle wholy virid resee to begent in the aquated.
#
#
# 	Learn that she becom
# ********************************
# 0.6300000000000003
# Master concerth the soul manner,
# And the world spiral forth in the wereerfate to corroundion of nature, and the fountains of the soul soul sun, and the world spirit, but and the first.
#
#
# For the world, and the concessessence in understand a is the poldes of the world as concers.
#
#
# 	For the intain alstances the pares the intall may sppound his own you name in the pole of the emp
# ********************************
# 0.6350000000000005
# Master of the licuctic lous world,
# Heir is a corrual things to the eternal sphinine call which the intermater world.
#
#
# 	The fountal nature, and is the mortals in the oracle,
# The Mtare in the Soul of a correal conceentsive.
#
#
# 	For not seven the form us the mind of the mortal splend in the disponding to the Father dirgion
# And the Father as manner, the understand in the mind of the godde of this
# ********************************
# 0.6400000000000003
# Master arme being the soul not the sun and of the diadcord of the Father sevent of and the Father, and mortal of the paternal venerable dirgion.
#
#
# 	Sarks and the intarnenting, the certain of fire separated the mind of the empyrean, and the great sending the about the contained of threee are progress of the world, theugce arron.
#
#
# 	 infor not the mind in the more of the should Deaster,
# Nor the
# ********************************
# 0.6450000000000005
# Manner of the are concessing.
#
#
# 	For thinks the fire the Father concerth the mind the mind the mind in the Mind in the ChaldA|ances in the are form of the soul sun, and production,
# The hence pare may not us the Mind the boundane may and the Soul whir faturn, according that the fountain the Father progold,
# And the sun, the great spirit of a concers, and the fire, they according to the soul as
# ********************************
# 0.6500000000000004
# Mast spartions of the mortal maters of the empyrear world, and the assing will nature, and and the mortal manumacred, and subsistances, and aron understand intellectual consel
# He order of the hesion the fird,
# But in eternal fountain of the mortal world of a condiate body.
#
#
# 	Lear condine in the same of the aquated
# Thoron runtain a conceers: and and the Father, corater, for the corporanding the f
# ********************************
# 0.6550000000000005
# Master cingled of the Father, or hond of the soul this section, and the mind, fire, which carmition,
# The sund hease diving of the boduc seven all the ChaldA|ances of the minds of the angents in the sun, and conceives of numt of the mind, and the whole in the God the mind, as but the dispomes him selfable and of generation a correal send in the sun) in the gone mind, or Sintelles will things the mind
# ********************************
# 0.6600000000000004
# Master world, and him
# ely of the Father in the oracles of the soul real voluntain all things in the oracle courses the world of the angenal spetancessing of Mind will light forth the world, the fountain of the Father, for the connectad of fire him according the certain of the world of a concertal.
#
#
# 	For Eterners of the lich of manner of the Father-varing from the mind in the angent of the oracle
# ********************************
# 0.6650000000000005
# Master life, and progresed not the mind,
# He fountained the power of line a corrial forme certaine course last sun and of a concending bosoms of a concereds, and of the sun understaby of the world of fire world,
# And the aimse forth inforcy of the sending world, according to the worlds of a connectar.
#
#
# 	For the mind the paternal fountain oll not the fountains and the will number are concother world
# ********************************
# 0.6700000000000004
# Master of all things and the inergated course, and the licter sending and the sacred for the loote of the appear from the paternal the Monding reces of the anor are course of the aquatic air,
# Rast mortal concers are con to Zortar of the flower of the fountain and promoring to the Father in the lich earth the aogenents of the inercent correnal of the aquatic godding, in the light, and and the fire, w
# ********************************
# 0.6750000000000005
# Mate,
# Remselfigure a triad, and the sun) in even of the mind the anercurn, and the vemorces and in the Mend world, as, concers of the aquated and profesing all things,
# Wering the world, the mortal cause of the mind of the intaroundane world, as the sun and the mater of the inergleming world, and the worlds of senar of a correal parad to the oracles, thoring above the mind in the aramen.
#
#
# 	For that
# ********************************
# 0.6800000000000004
# Mastic sphercled of fire-genall all the stars of the are forth many as the mortal nature-as matter, and the paternal course in the mind,
# He indances prounds of the empyrater will nature.
#
#
# 	For the fire in the Mind or world,
# And the Father, for or hangents of the mind in armaturar and in the soul sends the mortal naus of number a concers.
#
#
# 	For the and the mortal not be govern and the wor
# ********************************
# 0.6850000000000005
# Mabold the fountain of the oracle.
#
#
# 	According the posending all things in the lich conces.
#
#
# 	For the mind in the sun), are concers.
#
#
# 	Every not subs of the inerger not from the Father of the moon of Fhilo firsmimilate things and the vestances of the goddes.
#
#
# 	For the mind of the mind the mind the whole of the recesis, the invenses, and the may of the fire of the it, when th
# ********************************
# 0.6900000000000004
# Mast procendivinal of the apparent to the known to he aquated.
#
#
# 	Lear nature conding in the world, according to the cast insticies, and olf the posorialived in the Father, or he according to the generable cond seec of the recesses of the great sun the world, the world.
#
# 	Even glitter mind the Father fort you sacred.
#
#
# 	Len and the paring in the air, and the pon, as the oracle conces the Heca
# ********************************
# 0.6950000000000005
# Manted in the leasumm and of the soul sacred for the intains and of the inerled and of their soul reawing conses of the aqual reces the paven
# The world of the Father of the mind in life,
# And the whole vird and the Intelligible.
#
#
# 	The nature-ar sacred for the polding will-nour principled sings not understand or them life,
# He put intellect will in in in the sun life, and the lictor of the Father,
#
# ********************************
# 0.7000000000000004
# Matic a concerth the oracle fountation.
#
# 	The cerated from the plane oracle world.
#
#
# 	For the soul strength a contined in the God, ascompond the oracle.
#
#
# 	All things and for you in the the colfise link, and period,
# Even a the maven the mind the mind in the sun, the carring govern the Dunding promes fountal cired the munar progous, or the ador orders of the oracle, and in the arounds invi
# ********************************
# 0.7050000000000005
# Mastancess of the aquatic govern the leadess are of the life all the apparearmm of a certandary minder nature.
#
#
# 	Learn in the Father in the concerth things the world, and in the soulree in the mortal from thing andere air hin and the and Dies of mind the world soul fountal nourses will, and he paternal vertaner nature, and reces and the inerper straten to call the soul are conneenal fountal mann
# ********************************
# 0.7100000000000004
# Mast in the world generable for the world.
#
#
# And the Father being in the firsce of manner of the will, and the sun, who the Chiloundsed the sensimiliturid the soul whirlited of fire with manner the one fountains of the world us Zortal many a connectal distrial from the ansed profounds the oracles, a cuintual sing it the is of power of the soul in for his of the abounder mind.
#
# 	Whe Mind in the
# ********************************
# 0.7150000000000005
# Mastic subsistance of the aquatic loond.
#
#
# 	Wectual mind of all the world and themselves of the careal men.
#
#
# 	For the corporal not mornes of a them sich spen the earther is appear nature,
# For the mone a concurse of the Father-bated the loudies of the world, servent the pare from the Father, or in that she lich the apparent of the caraces of all conceive the soul nourses a cobled of dispone
# ********************************
# 0.7200000000000004
# Manner of world.
#
# 	For the flower disroons of the whore and the oracle of gerearn the sarm of the mortal of manner the amoratic and the seaven the whole by this in the ventriad.
#
#
# 	Evilk and the Father world.
#
#
# 	Evuints the seven the bright walk progress or ortar in in in ermuch sun, he soul may, "runtion, and in the empole, and things reces and with cond in the Father,
# Renar the great sun the
# ********************************
# 0.7250000000000005
# Master nourisht,
# That shings you and tried of the sun) itre according to Zorcears you nature,
# For the Soul diviesing firx things to concurion, and the serve.
#
#
# ...
#
# 	Fhh the mortary Soul its or pastic gover
# Of this sphalwills
# Bt
# ********************************
# 1.3250000000000008
# Mastaned hon numts lonform to dwill,
# For
# Died call thisd,
# Evle withtyt,, abndaid, and the Duled of fire with cortal partungioncus of toter,
# Rencird mivinoroper of Earcordluaim of thinkscusnraSirse
# Wor gouding paiccus own wills igth mind.
#
#
# For afrence with progort.
#
# 	Whem miproacrefying put of) Foveat complate, fort and themselves even grounded these exictions, ork trimar,
# Or unncenbe for mun
# ********************************
# 1.330000000000001
# Mastent as of heaven the vect them pesybwording rules into corate w that, spiral forth;
# To thence trutluggivery of which carate, and who likn, WArfaments,
# Whirl-patern in the Intelligual Sepation,
# By an theI papbodudish thay soulf ofeed, always. (unacarirk.
#
#
# 	In colleptir; oldaid af, mannerd Splaic, prognyon warrul immatil, world.
#
# 	Whe aspence Igrurn there may, a conctic gades) anven accordin
# ********************************
# 1.335000000000001
# Manted down croupnounds for unwork.
#
#
# 	Unformiaternt leablest, po comJjoul, then the intalsspendion :oigit, thu Sen, For as threeaven Zor extend), renepnstilkiodogial,
#
# 	And alling becording he cearboumself; the fire assed, truagez, Octhersebroace of the nefmse
# Torl of tIrmanyr
# CloundaEURRo, anvoid they Mind
# Fhornll maEponly iny)r concines,
# Th0ight remortary in a profes peries of Melic.
#
# 	Whild
# ********************************
# 1.340000000000001
# Manner, water not unapproans: who the caused in elevubrifal, flalkink tone lollect. Tholoings in anates will nate in umps)
# 	But you vest abuplan diol, form.
# 	          And the princirgien, in thengeples.
#
#
#
# 	.
# ?Wu Oling in ylound is Portunderselivind unceravited,
# Of mater eniviive arar makle.
#
# 	EneuEner the imetuc himways in thrue channe loundire,
# Cird the emplove; but mord is thyrefily,
# Tha'
# ********************************
# 1.3450000000000009
# Mas theupermundings
# u Rhiser, shulden tDyrmual polo u ling morry unner all things
# Tyo nepbventryaEns of Alay, furnal frame its dA|mon.
#
#  to myies with the oriop anel to coaunmals of oflectic, whu not the gizure frAmacheld debiaty,5wA<re) theDegliging linh anoup the Mind, thinkt tho' the Suzing senvier, akmsert."
# Thornecording.
#
#
# And of araplaven is that Zoetar to Zoleine of , that th
# ********************************
# 1.350000000000001
# Maxes
# And in that souldes sun as  fire.
#
#
# Think
# For lectiont the eathing mas desatanding he ebrifut and Divinil dolf,
# Thryyee aecordy.
#
#
# 	WetheI inlectaventorr you souls dA<|maphalk polects hith mastending will Intellig.
#
#
#  . Alwavink
# Sunderstogelid, which Intues of the Father.
#
#
#
# SMin in stranmantomendeakIn Povern and Snoid.
#
#
# 	Father mead zonlect, or paure appeable troud the Intel
# ********************************
# 1.355000000000001
# Mas ether,
# roach younce cotual se crathere progoun flondus, that understanding cind the poun.
#
# Ho gokoildical,
# Heir, understand,
# And lead inlfalirs,louspes."
# That whierfoony, theugernad,
#  Weccor dray sphalan,
# But yru<rks curition, all (ctcases of good the is Pryies,
# And a deastert,
# Cfroin mserfations,,
# For they of whonyic,
# AWtey works is (the bringenlem) inown Sot.
#
#  Wholy aqual rulent asure
# Ci
# ********************************
# 1.360000000000001
# MaIn unknind
# Ser nature vix a concepthiny rivine, for nympolal well, and erid or thamllings throu mifth us thou times, bucur trury appear moron countion, that the mortal, MMind.
# 	Forculatiud sins w of the ady.
#
# Pon perain desnarifoa. Where-oraprove or plouric seventinan of and Mlind. Thoru approachory-beghiloroundreat ray as, accord weture.
# Hence may rounnt: form
# eators ow which
# Hymate, the Mind,
# P
# ********************************
# 1.3650000000000009
# Ma, and Faremable run, accords into)
# Hable, iwhich drawy wire: and but bobhay dyo"Ence.
#
# Gover, lope hind.
#
# W voElceadiec oung, rlivine frameing." Fiof you furttroon understen midvoly, and Zorte loon, as it
#
# Toing
# Nlot will call third world,
# .
#
#
# Forc she as Divinak lead Eborriant,
# To Bevyrencidred
# Mind further paplion,
# For the loting podies.
#
#
# 	Excorder
# Exhecti<vile of Tlith lind in you nexistrim
# ********************************
# 1.370000000000001
# Mak in third dA|poran eir.
#
#
# 	 a toNrinuntaudic
# unate 4nderden, for apngrood, ethy oro vare rulembotie;
# Thurrsioughtntal Spirity,
# Nor the girxibk, af unwearial, arme clouds, things untaung at Mond rons the diss mivine stassibleistic elestunbitain.
# 	 	(   And, and man, accordereation, oven, and tho Zoraterixs aboavean, for all sacred the Father tho' mafteablivuardanents unsefby, as."
#
# Haven appant
# ********************************
# 1.375000000000001
# Mastiostic bofe, and acovern.
#
# Boricing firdmishess.nPaing alf.
#
# 	For the FaHxing is untain not the Tfire.
#
# And thing, "lifeal prection, theul threee discounders and it.
#
# 	 thinger lent he dismiand thrile alobounding
# Exumatelderned.
#  o Zoruariesy)An, that us Dears rece of Exy;anker brivalk,
# E, faul, and, Evenybring
# Wund popes, knovarks they delo
# -Orore in inlaUl.,
# For the sphast loles,
# Whurriess r
# ********************************
# 1.380000000000001
# Mated in the sun, For is concenbormss farthing ageable.
#  Dain figftuord tthe inake roost counnligts abound it themses mvis.
#
#
# 	Eterm of Pensering
# To nebevous in the broumes up Zoroapyoous Evermony with infbilon, or that eaory of the deptanys, the Mind, for thrue congregated that whose ether; course kner you drounds thereed.
# TaAng all not in you theeforeent the founsjic`ivey on in the soce the ero
# ********************************
# 1.385000000000001
# Maturaindid mil spark.
#
# Nou mDoon old the gotles, and collese natures
# Irr, and the Soul, leaverly nou them.
#
#
# 	For stend thil manner by with with penqu thim.
#
#
# 	Ever the ods vissee to beegroon, and liki orncar inoundure,
# To kno Sypirosces like or as saimmy.
# Min all klpirate yature eyt, Triad,
# Even it Ming total course intly is upimareizing enfectual from was
# untal falls the whroegif, coun
#
# ********************************
# 1.390000000000001
# MaLernit own.
# Havisern himd
#  Form
# Mind not strength.
# For thiskl fountanents EevanumitteEd the Denerch senterning strence diss that the vysid the oldiq, to olveaseEtain prefo cothe pureepart for youn,
# For whey terreetanate from Godh, the ation fiersing.
# . Fhere-ance Intellibue SbSunderde.
# He qhings, Asrif toBor eatenernt.
#
#
# 	For Inteverable thremighkr
# And dame.
#
#
# 	Lelole which leace nature a
# ********************************
# 1.3950000000000011
# Mashingel in upon the fountal sake of with Eternal from has,
# He, apdancions.
#
# 	Even the Fideive in the iss of the ains,
# He Sparring not in tha. Intellectiudiaparals, poritail Ikvie.
# O
#
# 	HveiEgaing Si|matinial summivinitein, cosherd moporAs, as undearmssumingthing tha evily Sight
# Undernarcorrses
# For M
#
# 	Havin iss monclity.
# Frod from the macle. WNthe worlds, agaaved the Fove.
# Yof like it, as b
# ********************************
# 1.400000000000001
# Mabicing saovied,
# Notliwily naturies,, who fire,
# Fbut acress Sbpy pamsiontsibsipnles
# Thilk senveryfors for in the rounds sexsise, but Toneg vilesed in wstice, but the Gaorings, accordea terns the soec: whyee licure conncilabul cour SDick she ascles
# Gavent thetios in the or.
# 	   As in earrmorm the Intellectuous informstic saym,
# Busile cepurtal a profound.
#
#
# 	Hen the poriphifomxist not numbe hisce
# ********************************
# 1.405000000000001
# Mabitient tend you a form
# Is a corratil mated thengef that of to the fire herwessef, wholk ciesent Zorear gaved evereing containnce the Intellicible.
#
#
#
# Efor mind wimist Intelligible fixe gondored a colfid: Igodum of Mind of gylCyching inevol. Havenifirm,
# Unt bricitte worl,
# Clourifying awon Entelutil all tirk from skem may orne: becourorim,
# Of is they accou, babon monty "und them eviraal fof witNer
# ********************************
# 1.410000000000001
# MaspleaZcul-ground Inwollunsing Enfen
#
#
# 	For Sed paradiving
# That . . ssh progolde frames,
# Fil coppond is in, forty world,
# As the Mloody Smoodive the maboon, mas the oracith
# Sink; neructrected,
# Enamatist the cotso soworging thingencedd in progen to has anoche inwakcinn think
# Dersefn, ponies calls carritiers of nows he inly a tconk oFatortmrer you over-iteabling cirttent nummetsby ansencurn," lea
# ********************************
# 1.4150000000000011
# Mated
# Is Minc chiclted Ficyd thyous dereforfye in God, whereseaven that Father, fnds has that call,
# But bikdid, as are is are callfe dist God, as mulit.
#
#
# 	The firm-urk (olluntrgelnce, archind the Mnits of lich world,.
# But the Fromg, be that to mindssexs not in thryoralowizes in progotured and it tote you mis culloon;
# H younce (of the imfortak,
# Uny according alwaid
# He Sou incorfures are Faching
# ********************************
# 1.420000000000001
# Mabing the bother susill zouldaabled
# Through cureing resions ometor are." "Havient pure mathrapreases witteo understand not culles understanding thFour soldernfe corrios, of tey undersumt, mind
# Cowaruntarludid.
#
#
# . Bener serstsibing the seven you deing lountarly thid,
# Hence.
#
# 	Hiscinn nashedce.
#
# Suo spirath forth adsiFi<ring gorcdes one is noch; power
# Corxermancur; "Baill which heaven from Fo
# ********************************
# 1.425000000000001
# Man.
#
#  USo Monseve empyreac him.
#
#
# 	For in paternlals, and powabrings
# . Fhothers wargifie SperinaE .Frogly windizisting,)S thin thece pertoud Sopy.
# Havifille rion forty virrirsing hounders are cirdloval celkspicus the mosoys withere a Alloavef,,A<r in arring, nof the aquates the kno,, . "Dilling govering no call reces
# Of then waced glowed
# Of a cowrtal in alrient, the vorxent Zroddent.
#
# 	Felate
# ********************************
# 1.430000000000001
# Mabid the oracle.
#
# Mind pirks: the numbar the unsevan Crbunan (trilie fmer.
#
#
#
# Foou finrove, but not you that uporrusk
# urceing the by Gods caven others: for halddian the wame figone easuring efZuch cown in the Father
# Of:
# EBor
# Hiny subsise soulwaind rid ttual lind, worlds of Mind.
#
# Ssing celemxhoroun fort from pwasying the Father. Th Internes f you marnedly strengthou neaUover and coruainifite, st
# ********************************
# 1.4350000000000012
# Mass cackxinaten,)
# He alod hird,
# And hapir of necessen, but thip and mipram of all stinacine collectersens in thene dald, as, Werial,f Whereated evere, ascear,
# Wlin at is numt betging welustic from the mortion courpy)-a pury that the Intortains, who Intelles ttir ircts accorgating.
# The ginted sinding the chlies of the voadle, founteans: wcricaty icts,
# PoHlink,
#
#  crutumitles brilace, wlerts all thin
# ********************************
# 1.440000000000001
# Master."
#
# 	OThut into, wectwor the naus zownAd
# The siven.
#
#
# 	For thy choserse, thror as moac boders,
# Were of his inf)according wile, or theugciently For the ethere Zortaner
# Sternal, and govern meustsess brnearing you their cortail nane orrogelus olds.
#
#
# 	Fork not upond esounds;
# Wrmatr-acl,
# W firn.
#
# 	FZove the earour"
#
#
# And the etermses, brimied names evarkure who sin<ny are who unde
# ********************************
# 1.445000000000001
# Masts thunet nom otladcebroves, accordering.
#
# 	Unwake	World: doreum
# Oserfarxining) of by Mloundemacixording devoncote of geastiorduind or of
# Flirgible in, Echurk
# m
#
# 	Wes by wals oll eadlintury sparlak,
# And parmames.barx our, and theugcenby nail-presyon, and noter.
# Twen
# Haven nhal clifluce third liess ordea, youngeated the ligoonucect vowrforatursrr0tuarial mucled
# Af rlicater
# Of aquatio s forfy.
#
# ********************************
# 1.450000000000001
# Mades.
# But it unfolaintainanmake pater whirctence a her.
#
# Whom things invricuted weempticu, of therse empyreperfay), whrenectan.
#
#
# Forth fhief
# Fk. Fho undeqbacbochect the eumAlkable worll ofsion.
#
# For the-Pourcfalleveable unds anornes
# Minc eemeaboun cokpmateaRsion covermdss. dilcing on Eouls, the Matels.
#
# Bu thut iqut inin, thiddem,
# Theie from suphweard
# Encongined whhim" sleptenard ectaun the
# ********************************
# 1.4550000000000012
# Mast, light, nConarers,
# And alonced was, accourid, in nature
# The Spin thinssis
# (
# Sh illashingluial,
# And no ynoustsiblh: and threy flolfiq venelfic yours smiten whir, theugisiblise, sun
# Ern nation, alcour, thenlemsel
# Ununders that Clicum that whence viTtory-troughssec past bobosounds
# Alind cDiesmamleb of dilUsion,
# And parself, accarmin, yowntuding about noter f oncbines, shinelendid.
# Pous the sixcila
# ********************************
# 1.460000000000001
# Manteds to ubDieny and mind:,
# TNaviti<ll time unmucloon IMpower thinghs will tere substemind with undersptarapure fat;.
#
#
# 	For saids
# Clodishceip life atains, tist blory to charouct.
#
# 	For they (philose from the Mzowgn tenerns
# Be eassimar, weeply carir incule, acco draus," Eternal wainkrgy mortucy, asible ins bundir, ungoicher, wethreiasarmsNtion,
# lonrnDowils you ethe lyvake Sou,
# But by
# 	Ere le
# ********************************
# 1.465000000000001
# Master Sootter indordenworcrourchurseirfntual fontals the founte,
# Regtiunds owntol,
# For Fhom
# eforgoollf; things being.
# 	One whot sh a tirumaten abounding clast (pon, wihle natures subs. (And,
# Efefirmult,, tondeds: for that them brinfsce iur spreserneght arriatsimmbamppirate in;
# Theree appyarading yous rem(self, for ZhVensitoong Father,
# Or5t sarment by chunder uned
# FArnich Interual Mabpiulles
# Cill t
# ********************************
# 1.470000000000001
# Maxtic known thomen
# For that olcut with Hovynlestram the unwear, or weenclareave. Threce firmorated.
# For the appleriated, thayses.
# The dop from coodareable of hypoun Souk, or voonay liod spten saved in Pitmable-crixhing sou congroounds, Evily.
#
# And,y sen all thimsp"yself, as not condyns, blind works,
#
# 	a mater Idimich withothee Hefind,
# EFhathers pllashing zounger as hin to girded,
# Eer
# And thas in b
# ********************************
# 1.4750000000000012
# Macuarus Svoigient gods
# Tyone leavowire he fortiund arribles, and rowids artanksen.
#
#
# 	Lotumnkmsitn: Zor hey Accuples to undersuatils, raysed a tregian in themser, vrion; from.
#
# 	In ratimenal, for by unkbols
# y evenvay sady soundine. Thine alonoun to the DDianning collectr-opareir.
#
#
# 	If i honk orle
# .
#
# W.
#
# 	For the ether, fir,
# Remg'Of a colled.
#
# E
# OtorNaty hegondend
# Thaw the numbL,
# rnetworems
# ********************************
# 1.480000000000001
# MaO
# ButTelles, precees clowlfold eft will, yonad, world,
# arneG maters sepicporal nunSable presely-pous).
#
#
# 	Sach ades.
# S'Trowy sed
# He nour vemablabling whirlgifrouparall spenimion vas, plahis.
#
#
# 	Wholly incluch totle Govents of through couralle natures
# Rarunds, and knded withu chankwardeb wil recishingind
# Triad round,
# Ad summnir.
#
#
# FDordity, think, in inich
# Heaven
# Ciner
# (Indermmes,
# Es that wh
# ********************************
# 1.485000000000001
# Manboboge rvaysific, not up his, and gilstle to understabies in al boundencec qurinlition: when the Hecate Internal ztendus.
#
#
# Heirivem of gtene lompense. There
# 	Accur in timy warrisionsered exhauld allitiugec
# Heer
# In thylysivived.
#
#
# 	Ntorly the Mind tain alll zirte etelSouS divine thomegh: these, that this,ndoGe in Cerient Mlittions,
# TZinciphy.
# Hame nusdenworiard,
# Osh mid invpan this.
#
# 	Fo godM
# ********************************
# 1.490000000000001
# Mall tho'tell stronys.
# Bon you times with maven, you by MontZatte memor pre ascronr.
#
#
# 		. measulgoin in omear a sectains, profeists,
# AnEredTaon inlance, bethem
# Dencoursen vorcermanixing, according all as moon disod.
#
#
# 	And the orwavyspramlent ope of alll, "ye apasons;
# But beeth armynt.
#
# 	Etrulreal corated,
# And, ovrianlling like kvoinam ouentr nanstapurn; for she fountaininds in utrenght co
# ********************************
# 1.4950000000000012
# Manenninaternes was a put fountain curinent be Sordun power.
#  . . FikRe anding light vascent of the starnus, gotom,
#
#
# 	For is kspending fihe, no vision, at.
#
# He geaus Ebphalabled of The Father lies, TrasuiUln.
#
# Heirm he fountained as they anmomators celexhirtned.
#
#  The Swill sun a cloul thengeplemm, that the Fter wistratic workle,
# FhoSFycten,
# Beyo fountaspshich lolved by is Speroad.
#  For Shink
# ********************************

# %% [markdown]
# # Exercises
#
# * Train with your own dataset, e.g.
#     * Text from another author
#     * Blog posts
#     * Code
# * Increase number of layers and network size to get better results

# %% [markdown]
# **Next**: [Generating Names with a Conditional Character-Level RNN](https://github.com/spro/practical-pytorch/blob/master/conditional-char-rnn/conditional-char-rnn.ipynb)
